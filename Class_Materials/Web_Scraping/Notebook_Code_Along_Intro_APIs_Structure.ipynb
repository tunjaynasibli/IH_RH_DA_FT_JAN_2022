# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
import pandas as pd
# json to pandas dataframe

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '20285068578',
#   'type': 'CreateEvent',
#   'actor': {'id': 52290251,
#    'login': 'botcopado',
#    'display_login': 'botcopado',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/botcopado',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52290251?'},
#   'repo': {'id': 459937563,
#    'name': 'botcopado/moeldv_BSZJV3KQ',
#    'url': 'https://api.github.com/repos/botcopado/moeldv_BSZJV3KQ'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-02-16T09:35:39Z'},
#  {'id': '20285068574',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 91113035,
#    'login': 'DmitriyLewen',
#    'display_login': 'DmitriyLewen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DmitriyLewen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91113035?'},
#   'repo': {'id': 75539205,
#    'name': 'aquasecurity/postee',
#    'url': 'https://api.github.com/repos/aquasecurity/postee'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/aquasecurity/postee/pulls/comments/807724292',
#     'pull_request_review_id': 884216807,
#     'id': 807724292,
#     'node_id': 'PRRC_kwDOBICjBc4wJOUE',
#     'diff_hunk': '@@ -285,6 +273,114 @@ func createMetaProject(c *jira.Client, project string) (*jira.MetaProject, error\n \treturn metaProject, nil\n }\n \n+func createIssueType(ctx *JiraAPI, metaProject *jira.MetaProject) error {\n+\tif ctx.Issuetype != "" {\n+\t\tfor _, issueType := range metaProject.IssueTypes {\n+\t\t\tif ctx.Issuetype == issueType.Name { // search issueType in REST API\n+\t\t\t\treturn nil\n+\t\t\t}\n+\t\t}\n+\t\treturn fmt.Errorf("project %q don\'t have issueType %q", metaProject.Name, ctx.Issuetype)\n+\t} else {\n+\t\tfor _, issueType := range metaProject.IssueTypes {\n+\t\t\tif issueType.Name == defaultIssueType { //search default issueType in REST API\n+\t\t\t\tctx.Issuetype = defaultIssueType\n+\t\t\t\treturn nil\n+\t\t\t}\n+\t\t}\n+\t\tif len(metaProject.IssueTypes) > 0 { // use 1st issueType from REST API\n+\t\t\tctx.Issuetype = metaProject.IssueTypes[0].Name\n+\t\t\treturn nil\n+\t\t} else {\n+\t\t\treturn fmt.Errorf("project %q don\'t have issueTypes", metaProject.Name)\n+\t\t}\n+\t}\n+}\n+\n+var createIssuePriority = func(ctx *JiraAPI, client *jira.Client) error {',
#     'path': 'outputs/jira.go',
#     'position': None,
#     'original_position': 141,
#     'commit_id': '127d5170b3b1624eb3ad6cdc6651cb46b2ee95fb',
#     'original_commit_id': '8f24426acdcbe2286b0bc605a099592a06105432',
#     'user': {'login': 'DmitriyLewen',
#      'id': 91113035,
#      'node_id': 'MDQ6VXNlcjkxMTEzMDM1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/91113035?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/DmitriyLewen',
#      'html_url': 'https://github.com/DmitriyLewen',
#      'followers_url': 'https://api.github.com/users/DmitriyLewen/followers',
#      'following_url': 'https://api.github.com/users/DmitriyLewen/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DmitriyLewen/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/DmitriyLewen/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DmitriyLewen/subscriptions',
#      'organizations_url': 'https://api.github.com/users/DmitriyLewen/orgs',
#      'repos_url': 'https://api.github.com/users/DmitriyLewen/repos',
#      'events_url': 'https://api.github.com/users/DmitriyLewen/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/DmitriyLewen/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Done',
#     'created_at': '2022-02-16T09:35:39Z',
#     'updated_at': '2022-02-16T09:35:39Z',
#     'html_url': 'https://github.com/aquasecurity/postee/pull/271#discussion_r807724292',
#     'pull_request_url': 'https://api.github.com/repos/aquasecurity/postee/pulls/271',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/aquasecurity/postee/pulls/comments/807724292'},
#      'html': {'href': 'https://github.com/aquasecurity/postee/pull/271#discussion_r807724292'},
#      'pull_request': {'href': 'https://api.github.com/repos/aquasecurity/postee/pulls/271'}},
#     'reactions': {'url': 'https://api.github.com/repos/aquasecurity/postee/pulls/comments/807724292/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'start_line': None,
#     'original_start_line': None,
#     'start_side': None,
#     'line': None,
#     'original_line': 300,
#     'side': 'RIGHT',
#     'in_reply_to_id': 806739662},
#    'pull_request': {'url': 'https://api.github.com/repos/aquasecurity/postee/pulls/271',
#     'id': 839954069,
#     'node_id': 'PR_kwDOBICjBc4yEK6V',
#     'html_url': 'https://github.com/aquasecurity/postee/pull/271',
#     'diff_url': 'https://github.com/aquasecurity/postee/pull/271.diff',
#     'patch_url': 'https://github.com/aquasecurity/postee/pull/271.patch',
#     'issue_url': 'https://api.github.com/repos/aquasecurity/postee/issues/271',
#     'number': 271,
#     'state': 'open',
#     'locked': False,
#     'title': 'feat(jira): add support for non-English localization',
#     'user': {'login': 'DmitriyLewen',
#      'id': 91113035,
#      'node_id': 'MDQ6VXNlcjkxMTEzMDM1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/91113035?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/DmitriyLewen',
#      'html_url': 'https://github.com/DmitriyLewen',
#      'followers_url': 'https://api.github.com/users/DmitriyLewen/followers',
#      'following_url': 'https://api.github.com/users/DmitriyLewen/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DmitriyLewen/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/DmitriyLewen/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DmitriyLewen/subscriptions',
#      'organizations_url': 'https://api.github.com/users/DmitriyLewen/orgs',
#      'repos_url': 'https://api.github.com/users/DmitriyLewen/repos',
#      'events_url': 'https://api.github.com/users/DmitriyLewen/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/DmitriyLewen/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '## Description\r\nAdded support for non-English localization.\r\n\r\n## Issues\r\n\r\n- aquasecurity/postee/issues/255',
#     'created_at': '2022-02-04T06:00:50Z',
#     'updated_at': '2022-02-16T09:35:39Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'f436d5218de6d206ac65d736ae377d1fc805c400',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': True,
#     'commits_url': 'https://api.github.com/repos/aquasecurity/postee/pulls/271/commits',
#     'review_comments_url': 'https://api.github.com/repos/aquasecurity/postee/pulls/271/comments',
#     'review_comment_url': 'https://api.github.com/repos/aquasecurity/postee/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/aquasecurity/postee/issues/271/comments',
#     'statuses_url': 'https://api.github.com/repos/aquasecurity/postee/statuses/127d5170b3b1624eb3ad6cdc6651cb46b2ee95fb',
#     'head': {'label': 'DmitriyLewen:issue255',
#      'ref': 'issue255',
#      'sha': '127d5170b3b1624eb3ad6cdc6651cb46b2ee95fb',
#      'user': {'login': 'DmitriyLewen',
#       'id': 91113035,
#       'node_id': 'MDQ6VXNlcjkxMTEzMDM1',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/91113035?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/DmitriyLewen',
#       'html_url': 'https://github.com/DmitriyLewen',
#       'followers_url': 'https://api.github.com/users/DmitriyLewen/followers',
#       'following_url': 'https://api.github.com/users/DmitriyLewen/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/DmitriyLewen/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/DmitriyLewen/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/DmitriyLewen/subscriptions',
#       'organizations_url': 'https://api.github.com/users/DmitriyLewen/orgs',
#       'repos_url': 'https://api.github.com/users/DmitriyLewen/repos',
#       'events_url': 'https://api.github.com/users/DmitriyLewen/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/DmitriyLewen/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 420998478,
#       'node_id': 'R_kgDOGRftTg',
#       'name': 'postee',
#       'full_name': 'DmitriyLewen/postee',
#       'private': False,
#       'owner': {'login': 'DmitriyLewen',
#        'id': 91113035,
#        'node_id': 'MDQ6VXNlcjkxMTEzMDM1',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/91113035?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/DmitriyLewen',
#        'html_url': 'https://github.com/DmitriyLewen',
#        'followers_url': 'https://api.github.com/users/DmitriyLewen/followers',
#        'following_url': 'https://api.github.com/users/DmitriyLewen/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/DmitriyLewen/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/DmitriyLewen/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/DmitriyLewen/subscriptions',
#        'organizations_url': 'https://api.github.com/users/DmitriyLewen/orgs',
#        'repos_url': 'https://api.github.com/users/DmitriyLewen/repos',
#        'events_url': 'https://api.github.com/users/DmitriyLewen/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/DmitriyLewen/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/DmitriyLewen/postee',
#       'description': 'Integrate Aqua Security vulnerability scanning with ALM systems (JIRA, ServiceNow) and messaging systems (MS Teams, Slack and Simple Email)',
#       'fork': True,
#       'url': 'https://api.github.com/repos/DmitriyLewen/postee',
#       'forks_url': 'https://api.github.com/repos/DmitriyLewen/postee/forks',
#       'keys_url': 'https://api.github.com/repos/DmitriyLewen/postee/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/DmitriyLewen/postee/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/DmitriyLewen/postee/teams',
#       'hooks_url': 'https://api.github.com/repos/DmitriyLewen/postee/hooks',
#       'issue_events_url': 'https://api.github.com/repos/DmitriyLewen/postee/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/DmitriyLewen/postee/events',
#       'assignees_url': 'https://api.github.com/repos/DmitriyLewen/postee/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/DmitriyLewen/postee/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/DmitriyLewen/postee/tags',
#       'blobs_url': 'https://api.github.com/repos/DmitriyLewen/postee/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/DmitriyLewen/postee/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/DmitriyLewen/postee/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/DmitriyLewen/postee/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/DmitriyLewen/postee/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/DmitriyLewen/postee/languages',
#       'stargazers_url': 'https://api.github.com/repos/DmitriyLewen/postee/stargazers',
#       'contributors_url': 'https://api.github.com/repos/DmitriyLewen/postee/contributors',
#       'subscribers_url': 'https://api.github.com/repos/DmitriyLewen/postee/subscribers',
#       'subscription_url': 'https://api.github.com/repos/DmitriyLewen/postee/subscription',
#       'commits_url': 'https://api.github.com/repos/DmitriyLewen/postee/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/DmitriyLewen/postee/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/DmitriyLewen/postee/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/DmitriyLewen/postee/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/DmitriyLewen/postee/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/DmitriyLewen/postee/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/DmitriyLewen/postee/merges',
#       'archive_url': 'https://api.github.com/repos/DmitriyLewen/postee/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/DmitriyLewen/postee/downloads',
#       'issues_url': 'https://api.github.com/repos/DmitriyLewen/postee/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/DmitriyLewen/postee/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/DmitriyLewen/postee/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/DmitriyLewen/postee/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/DmitriyLewen/postee/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/DmitriyLewen/postee/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/DmitriyLewen/postee/deployments',
#       'created_at': '2021-10-25T11:38:44Z',
#       'updated_at': '2021-12-27T04:46:58Z',
#       'pushed_at': '2022-02-16T09:31:08Z',
#       'git_url': 'git://github.com/DmitriyLewen/postee.git',
#       'ssh_url': 'git@github.com:DmitriyLewen/postee.git',
#       'clone_url': 'https://github.com/DmitriyLewen/postee.git',
#       'svn_url': 'https://github.com/DmitriyLewen/postee',
#       'homepage': '',
#       'size': 3179,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'aquasecurity:main',
#      'ref': 'main',
#      'sha': '1746a11f397b48b4f53c102513e0ad3daafcbd3e',
#      'user': {'login': 'aquasecurity',
#       'id': 12783832,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyNzgzODMy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/12783832?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/aquasecurity',
#       'html_url': 'https://github.com/aquasecurity',
#       'followers_url': 'https://api.github.com/users/aquasecurity/followers',
#       'following_url': 'https://api.github.com/users/aquasecurity/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/aquasecurity/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/aquasecurity/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/aquasecurity/subscriptions',
#       'organizations_url': 'https://api.github.com/users/aquasecurity/orgs',
#       'repos_url': 'https://api.github.com/users/aquasecurity/repos',
#       'events_url': 'https://api.github.com/users/aquasecurity/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/aquasecurity/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 75539205,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3NTUzOTIwNQ==',
#       'name': 'postee',
#       'full_name': 'aquasecurity/postee',
#       'private': False,
#       'owner': {'login': 'aquasecurity',
#        'id': 12783832,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyNzgzODMy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/12783832?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/aquasecurity',
#        'html_url': 'https://github.com/aquasecurity',
#        'followers_url': 'https://api.github.com/users/aquasecurity/followers',
#        'following_url': 'https://api.github.com/users/aquasecurity/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/aquasecurity/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/aquasecurity/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/aquasecurity/subscriptions',
#        'organizations_url': 'https://api.github.com/users/aquasecurity/orgs',
#        'repos_url': 'https://api.github.com/users/aquasecurity/repos',
#        'events_url': 'https://api.github.com/users/aquasecurity/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/aquasecurity/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/aquasecurity/postee',
#       'description': 'Integrate Aqua Security vulnerability scanning with ALM systems (JIRA, ServiceNow) and messaging systems (MS Teams, Slack and Simple Email)',
#       'fork': False,
#       'url': 'https://api.github.com/repos/aquasecurity/postee',
#       'forks_url': 'https://api.github.com/repos/aquasecurity/postee/forks',
#       'keys_url': 'https://api.github.com/repos/aquasecurity/postee/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/aquasecurity/postee/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/aquasecurity/postee/teams',
#       'hooks_url': 'https://api.github.com/repos/aquasecurity/postee/hooks',
#       'issue_events_url': 'https://api.github.com/repos/aquasecurity/postee/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/aquasecurity/postee/events',
#       'assignees_url': 'https://api.github.com/repos/aquasecurity/postee/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/aquasecurity/postee/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/aquasecurity/postee/tags',
#       'blobs_url': 'https://api.github.com/repos/aquasecurity/postee/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/aquasecurity/postee/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/aquasecurity/postee/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/aquasecurity/postee/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/aquasecurity/postee/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/aquasecurity/postee/languages',
#       'stargazers_url': 'https://api.github.com/repos/aquasecurity/postee/stargazers',
#       'contributors_url': 'https://api.github.com/repos/aquasecurity/postee/contributors',
#       'subscribers_url': 'https://api.github.com/repos/aquasecurity/postee/subscribers',
#       'subscription_url': 'https://api.github.com/repos/aquasecurity/postee/subscription',
#       'commits_url': 'https://api.github.com/repos/aquasecurity/postee/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/aquasecurity/postee/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/aquasecurity/postee/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/aquasecurity/postee/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/aquasecurity/postee/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/aquasecurity/postee/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/aquasecurity/postee/merges',
#       'archive_url': 'https://api.github.com/repos/aquasecurity/postee/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/aquasecurity/postee/downloads',
#       'issues_url': 'https://api.github.com/repos/aquasecurity/postee/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/aquasecurity/postee/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/aquasecurity/postee/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/aquasecurity/postee/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/aquasecurity/postee/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/aquasecurity/postee/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/aquasecurity/postee/deployments',
#       'created_at': '2016-12-04T13:29:28Z',
#       'updated_at': '2022-02-10T20:11:38Z',
#       'pushed_at': '2022-02-16T09:31:10Z',
#       'git_url': 'git://github.com/aquasecurity/postee.git',
#       'ssh_url': 'git@github.com:aquasecurity/postee.git',
#       'clone_url': 'https://github.com/aquasecurity/postee.git',
#       'svn_url': 'https://github.com/aquasecurity/postee',
#       'homepage': '',
#       'size': 2981,
#       'stargazers_count': 88,
#       'watchers_count': 88,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 29,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 32,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['aqua', 'jira', 'ticket'],
#       'visibility': 'public',
#       'forks': 29,
#       'open_issues': 32,
#       'watchers': 88,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/aquasecurity/postee/pulls/271'},
#      'html': {'href': 'https://github.com/aquasecurity/postee/pull/271'},
#      'issue': {'href': 'https://api.github.com/repos/aquasecurity/postee/issues/271'},
#      'comments': {'href': 'https://api.github.com/repos/aquasecurity/postee/issues/271/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/aquasecurity/postee/pulls/271/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/aquasecurity/postee/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/aquasecurity/postee/pulls/271/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/aquasecurity/postee/statuses/127d5170b3b1624eb3ad6cdc6651cb46b2ee95fb'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2022-02-16T09:35:39Z',
#   'org': {'id': 12783832,
#    'login': 'aquasecurity',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aquasecurity',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12783832?'}},
#  {'id': '20285068601',
#   'type': 'ForkEvent',
#   'actor': {'id': 84758240,
#    'login': 'aliang-bigdata',
#    'display_login': 'aliang-bigdata',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aliang-bigdata',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84758240?'},
#   'repo': {'id': 364195197,
#    'name': 'findify/featury',
#    'url': 'https://api.github.com/repos/findify/featury'},
#   'payload': {'forkee': {'id': 459937672,
#     'node_id': 'R_kgDOG2oXiA',
#     'name': 'featury',
#     'full_name': 'aliang-bigdata/featury',
#     'private': False,
#     'owner': {'login': 'aliang-bigdata',
#      'id': 84758240,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg0NzU4MjQw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/84758240?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/aliang-bigdata',
#      'html_url': 'https://github.com/aliang-bigdata',
#      'followers_url': 'https://api.github.com/users/aliang-bigdata/followers',
#      'following_url': 'https://api.github.com/users/aliang-bigdata/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/aliang-bigdata/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/aliang-bigdata/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/aliang-bigdata/subscriptions',
#      'organizations_url': 'https://api.github.com/users/aliang-bigdata/orgs',
#      'repos_url': 'https://api.github.com/users/aliang-bigdata/repos',
#      'events_url': 'https://api.github.com/users/aliang-bigdata/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/aliang-bigdata/received_events',
#      'type': 'Organization',
#      'site_admin': False},
#     'html_url': 'https://github.com/aliang-bigdata/featury',
#     'description': 'Friendly ML feature store',
#     'fork': True,
#     'url': 'https://api.github.com/repos/aliang-bigdata/featury',
#     'forks_url': 'https://api.github.com/repos/aliang-bigdata/featury/forks',
#     'keys_url': 'https://api.github.com/repos/aliang-bigdata/featury/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/aliang-bigdata/featury/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/aliang-bigdata/featury/teams',
#     'hooks_url': 'https://api.github.com/repos/aliang-bigdata/featury/hooks',
#     'issue_events_url': 'https://api.github.com/repos/aliang-bigdata/featury/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/aliang-bigdata/featury/events',
#     'assignees_url': 'https://api.github.com/repos/aliang-bigdata/featury/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/aliang-bigdata/featury/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/aliang-bigdata/featury/tags',
#     'blobs_url': 'https://api.github.com/repos/aliang-bigdata/featury/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/aliang-bigdata/featury/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/aliang-bigdata/featury/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/aliang-bigdata/featury/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/aliang-bigdata/featury/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/aliang-bigdata/featury/languages',
#     'stargazers_url': 'https://api.github.com/repos/aliang-bigdata/featury/stargazers',
#     'contributors_url': 'https://api.github.com/repos/aliang-bigdata/featury/contributors',
#     'subscribers_url': 'https://api.github.com/repos/aliang-bigdata/featury/subscribers',
#     'subscription_url': 'https://api.github.com/repos/aliang-bigdata/featury/subscription',
#     'commits_url': 'https://api.github.com/repos/aliang-bigdata/featury/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/aliang-bigdata/featury/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/aliang-bigdata/featury/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/aliang-bigdata/featury/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/aliang-bigdata/featury/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/aliang-bigdata/featury/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/aliang-bigdata/featury/merges',
#     'archive_url': 'https://api.github.com/repos/aliang-bigdata/featury/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/aliang-bigdata/featury/downloads',
#     'issues_url': 'https://api.github.com/repos/aliang-bigdata/featury/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/aliang-bigdata/featury/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/aliang-bigdata/featury/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/aliang-bigdata/featury/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/aliang-bigdata/featury/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/aliang-bigdata/featury/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/aliang-bigdata/featury/deployments',
#     'created_at': '2022-02-16T09:35:39Z',
#     'updated_at': '2022-02-16T09:33:26Z',
#     'pushed_at': '2022-01-07T13:34:06Z',
#     'git_url': 'git://github.com/aliang-bigdata/featury.git',
#     'ssh_url': 'git@github.com:aliang-bigdata/featury.git',
#     'clone_url': 'https://github.com/aliang-bigdata/featury.git',
#     'svn_url': 'https://github.com/aliang-bigdata/featury',
#     'homepage': None,
#     'size': 463,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'apache-2.0',
#      'name': 'Apache License 2.0',
#      'spdx_id': 'Apache-2.0',
#      'url': 'https://api.github.com/licenses/apache-2.0',
#      'node_id': 'MDc6TGljZW5zZTI='},
#     'allow_forking': True,
#     'is_template': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2022-02-16T09:35:39Z',
#   'org': {'id': 5618622,
#    'login': 'findify',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/findify',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5618622?'}},
#  {'id': '20285068583',
#   'type': 'CreateEvent',
#   'actor': {'id': 99338701,
#    'login': 'LidiaMoreno',
#    'display_login': 'LidiaMoreno',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LidiaMoreno',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99338701?'},
#   'repo': {'id': 459937671,
#    'name': 'LidiaMoreno/SolucionesTema2',
#    'url': 'https://api.github.com/repos/LidiaMoreno/SolucionesTema2'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-02-16T09:35:39Z'},
#  {'id': '20285068591',
#   'type': 'PushEvent',
#   'actor': {'id': 99035456,
#    'login': 'prasanthgoli',
#    'display_login': 'prasanthgoli',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/prasanthgoli',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99035456?'},
#   'repo': {'id': 458164143,
#    'name': 'prasanthgoli/my-ansible_nit_e_6',
#    'url': 'https://api.github.com/repos/prasanthgoli/my-ansible_nit_e_6'},
#   'payload': {'push_id': 9116270265,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b45ffb1d2f1c2f77c48f0345ac339f97cd106113',
#    'before': '1a2b088f7382f7c1d64e804e84ae67e8a277058e',
#    'commits': [{'sha': 'b45ffb1d2f1c2f77c48f0345ac339f97cd106113',
#      'author': {'email': 'golivenkataprasanthkumar@gmail.com',
#       'name': 'prasanthgoli'},
#      'message': 'ansible',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/prasanthgoli/my-ansible_nit_e_6/commits/b45ffb1d2f1c2f77c48f0345ac339f97cd106113'}]},
#   'public': True,
#   'created_at': '2022-02-16T09:35:39Z'},
#  {'id': '20285068577',
#   'type': 'CreateEvent',
#   'actor': {'id': 52290251,
#    'login': 'botcopado',
#    'display_login': 'botcopado',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/botcopado',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52290251?'},
#   'repo': {'id': 459937550,
#    'name': 'botcopado/moeldv_GMNFDVHO',
#    'url': 'https://api.github.com/repos/botcopado/moeldv_GMNFDVHO'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-02-16T09:35:39Z'},
#  {'id': '20285068575',
#   'type': 'PushEvent',
#   'actor': {'id': 5656720,
#    'login': 'dyakovri',
#    'display_login': 'dyakovri',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dyakovri',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5656720?'},
#   'repo': {'id': 433204426,
#    'name': 'profcomff/data-pipelines',
#    'url': 'https://api.github.com/repos/profcomff/data-pipelines'},
#   'payload': {'push_id': 9116270262,
#    'size': 5,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '57d4ae42b37c5ce24c5d76fc9353c53190e6afb4',
#    'before': '0ebf9c0f8ad4f46aef11bde54843005c86415fa6',
#    'commits': [{'sha': '46d7856bfb11aaef3d19ae37b6382a2ad3464ecc',
#      'author': {'email': 'andrey.luk10@gmail.com', 'name': 'Daiwery'},
#      'message': 'Odd and even.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/profcomff/data-pipelines/commits/46d7856bfb11aaef3d19ae37b6382a2ad3464ecc'},
#     {'sha': 'e03fd5555b0766ccbbbaeeddc36a60dde450ac97',
#      'author': {'email': 'andrey.luk10@gmail.com', 'name': 'Daiwery'},
#      'message': 'Исправление ошибок.',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/profcomff/data-pipelines/commits/e03fd5555b0766ccbbbaeeddc36a60dde450ac97'},
#     {'sha': '6c4998e5c44eb6bd5901feb1a29f0c135f4f9dd1',
#      'author': {'email': 'andrey.luk10@gmail.com', 'name': 'Daiwery'},
#      'message': 'Done',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/profcomff/data-pipelines/commits/6c4998e5c44eb6bd5901feb1a29f0c135f4f9dd1'},
#     {'sha': 'f4521e75d44183c81dcd22beae1d1e2447e87ae7',
#      'author': {'email': 'andrey.luk10@gmail.com', 'name': 'Daiwery'},
#      'message': 'Delete .idea',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/profcomff/data-pipelines/commits/f4521e75d44183c81dcd22beae1d1e2447e87ae7'},
#     {'sha': '57d4ae42b37c5ce24c5d76fc9353c53190e6afb4',
#      'author': {'email': 'diakov.ri16@physics.msu.ru', 'name': 'Dyakov Roman'},
#      'message': 'Merge pull request #4 from profcomff/Andrey\n\nOdd and even.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/profcomff/data-pipelines/commits/57d4ae42b37c5ce24c5d76fc9353c53190e6afb4'}]},
#   'public': True,
#   'created_at': '2022-02-16T09:35:39Z',
#   'org': {'id': 94626404,
#    'login': 'profcomff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/profcomff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94626404?'}},
#  {'id': '20285068559',
#   'type': 'PushEvent',
#   'actor': {'id': 43138394,
#    'login': 'mrasw',
#    'display_login': 'mrasw',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mrasw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43138394?'},
#   'repo': {'id': 459923433,
#    'name': 'mrasw/ChiefAGRO',
#    'url': 'https://api.github.com/repos/mrasw/ChiefAGRO'},
#   'payload': {'push_id': 9116270263,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd078ba1afa8e0caad4f0292e715d9ce5dc9cc34a',
#    'before': '4b7468f00e633d917ec59589e0d4fd963c2cb2ea',
#    'commits': [{'sha': 'd078ba1afa8e0caad4f0292e715d9ce5dc9cc34a',
#      'author': {'email': '43138394+mrasw@users.noreply.github.com',
#       'name': 'tux0112'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mrasw/ChiefAGRO/commits/d078ba1afa8e0caad4f0292e715d9ce5dc9cc34a'}]},
#   'public': True,
#   'created_at': '2022-02-16T09:35:39Z'},
#  {'id': '20285068582',
#   'type': 'CreateEvent',
#   'actor': {'id': 86326137,
#    'login': 'bot-monkey-7',
#    'display_login': 'bot-monkey-7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bot-monkey-7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/86326137?'},
#   'repo': {'id': 356421872,
#    'name': 'test-organization-kkjeer/bot-validation-2',
#    'url': 'https://api.github.com/repos/test-organization-kkjeer/bot-validation-2'},
#   'payload': {'ref': 'monkey-branch-d8yy7n',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-02-16T09:35:39Z',
#   'org': {'id': 47997193,
#    'login': 'test-organization-kkjeer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/test-organization-kkjeer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47997193?'}},
#  {'id': '20285068529',
#   'type': 'CreateEvent',
#   'actor': {'id': 79044155,
#    'login': 'himdrakibulislam',
#    'display_login': 'himdrakibulislam',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/himdrakibulislam',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79044155?'},
#   'repo': {'id': 459937669,
#    'name': 'himdrakibulislam/Education',
#    'url': 'https://api.github.com/repos/himdrakibulislam/Education'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-02-16T09:35:39Z'},
#  {'id': '20285068565',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 422531348,
#    'name': 'choice-form/mono-apps',
#    'url': 'https://api.github.com/repos/choice-form/mono-apps'},
#   'payload': {'action': 'closed',
#    'number': 439,
#    'pull_request': {'url': 'https://api.github.com/repos/choice-form/mono-apps/pulls/439',
#     'id': 854183713,
#     'node_id': 'PR_kwDOGS9RFM4y6c8h',
#     'html_url': 'https://github.com/choice-form/mono-apps/pull/439',
#     'diff_url': 'https://github.com/choice-form/mono-apps/pull/439.diff',
#     'patch_url': 'https://github.com/choice-form/mono-apps/pull/439.patch',
#     'issue_url': 'https://api.github.com/repos/choice-form/mono-apps/issues/439',
#     'number': 439,
#     'state': 'closed',
#     'locked': False,
#     'title': 'fix(renovate): update dependency @antv/s2 to v1.9.0',
#     'user': {'login': 'renovate[bot]',
#      'id': 29139614,
#      'node_id': 'MDM6Qm90MjkxMzk2MTQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/2740?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/renovate%5Bbot%5D',
#      'html_url': 'https://github.com/apps/renovate',
#      'followers_url': 'https://api.github.com/users/renovate%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/renovate%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/renovate%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/renovate%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/renovate%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/renovate%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/renovate%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/renovate%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/renovate%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': "[![WhiteSource Renovate](https://app.renovatebot.com/images/banner.svg)](https://renovatebot.com)\n\nThis PR contains the following updates:\n\n| Package | Change | Age | Adoption | Passing | Confidence |\n|---|---|---|---|---|---|\n| [@antv/s2](https://s2.antv.vision) ([source](https://togithub.com/antvis/S2)) | [`1.8.0` -> `1.9.0`](https://renovatebot.com/diffs/npm/@antv%2fs2/1.8.0/1.9.0) | [![age](https://badges.renovateapi.com/packages/npm/@antv%2fs2/1.9.0/age-slim)](https://docs.renovatebot.com/merge-confidence/) | [![adoption](https://badges.renovateapi.com/packages/npm/@antv%2fs2/1.9.0/adoption-slim)](https://docs.renovatebot.com/merge-confidence/) | [![passing](https://badges.renovateapi.com/packages/npm/@antv%2fs2/1.9.0/compatibility-slim/1.8.0)](https://docs.renovatebot.com/merge-confidence/) | [![confidence](https://badges.renovateapi.com/packages/npm/@antv%2fs2/1.9.0/confidence-slim/1.8.0)](https://docs.renovatebot.com/merge-confidence/) |\n\n---\n\n### Release Notes\n\n<details>\n<summary>antvis/S2</summary>\n\n### [`v1.9.0`](https://togithub.com/antvis/S2/compare/@antv/s2-v1.8.0...@antv/s2-v1.9.0)\n\n[Compare Source](https://togithub.com/antvis/S2/compare/@antv/s2-v1.8.0...@antv/s2-v1.9.0)\n\n</details>\n\n---\n\n### Configuration\n\n📅 **Schedule**: At any time (no schedule defined).\n\n🚦 **Automerge**: Enabled.\n\n♻ **Rebasing**: Whenever PR becomes conflicted, or you tick the rebase/retry checkbox.\n\n🔕 **Ignore**: Close this PR and you won't be reminded about this update again.\n\n---\n\n - [ ] <!-- rebase-check -->If you want to rebase/retry this PR, click this checkbox.\n\n---\n\nThis PR has been generated by [WhiteSource Renovate](https://renovate.whitesourcesoftware.com). View repository job log [here](https://app.renovatebot.com/dashboard#github/choice-form/mono-apps).",
#     'created_at': '2022-02-16T09:35:37Z',
#     'updated_at': '2022-02-16T09:35:39Z',
#     'closed_at': '2022-02-16T09:35:39Z',
#     'merged_at': '2022-02-16T09:35:39Z',
#     'merge_commit_sha': 'ae863b97c5dcf824b5b60eed1f730c7e8f01d3bb',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 3505041831,
#       'node_id': 'LA_kwDOGS9RFM7Q6rGn',
#       'url': 'https://api.github.com/repos/choice-form/mono-apps/labels/%E7%B1%BB%E5%9E%8B:%20%E4%BE%9D%E8%B5%96',
#       'name': '类型: 依赖',
#       'color': '868D9F',
#       'default': False,
#       'description': '专门用于依赖更新，以区别于其他类型'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/choice-form/mono-apps/pulls/439/commits',
#     'review_comments_url': 'https://api.github.com/repos/choice-form/mono-apps/pulls/439/comments',
#     'review_comment_url': 'https://api.github.com/repos/choice-form/mono-apps/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/choice-form/mono-apps/issues/439/comments',
#     'statuses_url': 'https://api.github.com/repos/choice-form/mono-apps/statuses/be21e7877b4a7f8b18bc8aa6f06123c7652c12c6',
#     'head': {'label': 'choice-form:renovate/antv-s2-1.x',
#      'ref': 'renovate/antv-s2-1.x',
#      'sha': 'be21e7877b4a7f8b18bc8aa6f06123c7652c12c6',
#      'user': {'login': 'choice-form',
#       'id': 12053581,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyMDUzNTgx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/12053581?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/choice-form',
#       'html_url': 'https://github.com/choice-form',
#       'followers_url': 'https://api.github.com/users/choice-form/followers',
#       'following_url': 'https://api.github.com/users/choice-form/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/choice-form/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/choice-form/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/choice-form/subscriptions',
#       'organizations_url': 'https://api.github.com/users/choice-form/orgs',
#       'repos_url': 'https://api.github.com/users/choice-form/repos',
#       'events_url': 'https://api.github.com/users/choice-form/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/choice-form/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 422531348,
#       'node_id': 'R_kgDOGS9RFA',
#       'name': 'mono-apps',
#       'full_name': 'choice-form/mono-apps',
#       'private': False,
#       'owner': {'login': 'choice-form',
#        'id': 12053581,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjEyMDUzNTgx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/12053581?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/choice-form',
#        'html_url': 'https://github.com/choice-form',
#        'followers_url': 'https://api.github.com/users/choice-form/followers',
#        'following_url': 'https://api.github.com/users/choice-form/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/choice-form/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/choice-form/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/choice-form/subscriptions',
#        'organizations_url': 'https://api.github.com/users/choice-form/orgs',
#        'repos_url': 'https://api.github.com/users/choice-form/repos',
#        'events_url': 'https://api.github.com/users/choice-form/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/choice-form/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/choice-form/mono-apps',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/choice-form/mono-apps',
#       'forks_url': 'https://api.github.com/repos/choice-form/mono-apps/forks',
#       'keys_url': 'https://api.github.com/repos/choice-form/mono-apps/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/choice-form/mono-apps/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/choice-form/mono-apps/teams',
#       'hooks_url': 'https://api.github.com/repos/choice-form/mono-apps/hooks',
#       'issue_events_url': 'https://api.github.com/repos/choice-form/mono-apps/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/choice-form/mono-apps/events',
#       'assignees_url': 'https://api.github.com/repos/choice-form/mono-apps/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/choice-form/mono-apps/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/choice-form/mono-apps/tags',
#       'blobs_url': 'https://api.github.com/repos/choice-form/mono-apps/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/choice-form/mono-apps/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/choice-form/mono-apps/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/choice-form/mono-apps/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/choice-form/mono-apps/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/choice-form/mono-apps/languages',
#       'stargazers_url': 'https://api.github.com/repos/choice-form/mono-apps/stargazers',
#       'contributors_url': 'https://api.github.com/repos/choice-form/mono-apps/contributors',
#       'subscribers_url': 'https://api.github.com/repos/choice-form/mono-apps/subscribers',
#       'subscription_url': 'https://api.github.com/repos/choice-form/mono-apps/subscription',
#       'commits_url': 'https://api.github.com/repos/choice-form/mono-apps/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/choice-form/mono-apps/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/choice-form/mono-apps/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/choice-form/mono-apps/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/choice-form/mono-apps/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/choice-form/mono-apps/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/choice-form/mono-apps/merges',
#       'archive_url': 'https://api.github.com/repos/choice-form/mono-apps/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/choice-form/mono-apps/downloads',
#       'issues_url': 'https://api.github.com/repos/choice-form/mono-apps/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/choice-form/mono-apps/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/choice-form/mono-apps/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/choice-form/mono-apps/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/choice-form/mono-apps/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/choice-form/mono-apps/releases{/id}',
# ...
#       'subscriptions_url': 'https://api.github.com/users/ramprakashram/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ramprakashram/orgs',
#       'repos_url': 'https://api.github.com/users/ramprakashram/repos',
#       'events_url': 'https://api.github.com/users/ramprakashram/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ramprakashram/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 220639687,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjA2Mzk2ODc=',
#       'name': 'child-cam',
#       'full_name': 'ramprakashram/child-cam',
#       'private': False,
#       'owner': {'login': 'ramprakashram',
#        'id': 31797738,
#        'node_id': 'MDQ6VXNlcjMxNzk3NzM4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/31797738?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ramprakashram',
#        'html_url': 'https://github.com/ramprakashram',
#        'followers_url': 'https://api.github.com/users/ramprakashram/followers',
#        'following_url': 'https://api.github.com/users/ramprakashram/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ramprakashram/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ramprakashram/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ramprakashram/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ramprakashram/orgs',
#        'repos_url': 'https://api.github.com/users/ramprakashram/repos',
#        'events_url': 'https://api.github.com/users/ramprakashram/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ramprakashram/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ramprakashram/child-cam',
#       'description': 'A camera application focussed on fun-filled UI for children using Ionic Framework',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ramprakashram/child-cam',
#       'forks_url': 'https://api.github.com/repos/ramprakashram/child-cam/forks',
#       'keys_url': 'https://api.github.com/repos/ramprakashram/child-cam/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ramprakashram/child-cam/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ramprakashram/child-cam/teams',
#       'hooks_url': 'https://api.github.com/repos/ramprakashram/child-cam/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ramprakashram/child-cam/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ramprakashram/child-cam/events',
#       'assignees_url': 'https://api.github.com/repos/ramprakashram/child-cam/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ramprakashram/child-cam/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ramprakashram/child-cam/tags',
#       'blobs_url': 'https://api.github.com/repos/ramprakashram/child-cam/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ramprakashram/child-cam/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ramprakashram/child-cam/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ramprakashram/child-cam/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ramprakashram/child-cam/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ramprakashram/child-cam/languages',
#       'stargazers_url': 'https://api.github.com/repos/ramprakashram/child-cam/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ramprakashram/child-cam/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ramprakashram/child-cam/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ramprakashram/child-cam/subscription',
#       'commits_url': 'https://api.github.com/repos/ramprakashram/child-cam/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ramprakashram/child-cam/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ramprakashram/child-cam/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ramprakashram/child-cam/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ramprakashram/child-cam/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ramprakashram/child-cam/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ramprakashram/child-cam/merges',
#       'archive_url': 'https://api.github.com/repos/ramprakashram/child-cam/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ramprakashram/child-cam/downloads',
#       'issues_url': 'https://api.github.com/repos/ramprakashram/child-cam/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ramprakashram/child-cam/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ramprakashram/child-cam/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ramprakashram/child-cam/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ramprakashram/child-cam/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ramprakashram/child-cam/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ramprakashram/child-cam/deployments',
#       'created_at': '2019-11-09T12:34:45Z',
#       'updated_at': '2022-02-16T09:34:25Z',
#       'pushed_at': '2022-02-16T09:35:38Z',
#       'git_url': 'git://github.com/ramprakashram/child-cam.git',
#       'ssh_url': 'git@github.com:ramprakashram/child-cam.git',
#       'clone_url': 'https://github.com/ramprakashram/child-cam.git',
#       'svn_url': 'https://github.com/ramprakashram/child-cam',
#       'homepage': None,
#       'size': 3958,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 16,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 16,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'ramprakashram:master',
#      'ref': 'master',
#      'sha': '22819635cbfcf216859ae5179e03db6cb4194b68',
#      'user': {'login': 'ramprakashram',
#       'id': 31797738,
#       'node_id': 'MDQ6VXNlcjMxNzk3NzM4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/31797738?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ramprakashram',
#       'html_url': 'https://github.com/ramprakashram',
#       'followers_url': 'https://api.github.com/users/ramprakashram/followers',
#       'following_url': 'https://api.github.com/users/ramprakashram/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ramprakashram/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ramprakashram/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ramprakashram/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ramprakashram/orgs',
#       'repos_url': 'https://api.github.com/users/ramprakashram/repos',
#       'events_url': 'https://api.github.com/users/ramprakashram/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ramprakashram/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 220639687,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjA2Mzk2ODc=',
#       'name': 'child-cam',
#       'full_name': 'ramprakashram/child-cam',
#       'private': False,
#       'owner': {'login': 'ramprakashram',
#        'id': 31797738,
#        'node_id': 'MDQ6VXNlcjMxNzk3NzM4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/31797738?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ramprakashram',
#        'html_url': 'https://github.com/ramprakashram',
#        'followers_url': 'https://api.github.com/users/ramprakashram/followers',
#        'following_url': 'https://api.github.com/users/ramprakashram/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ramprakashram/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ramprakashram/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ramprakashram/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ramprakashram/orgs',
#        'repos_url': 'https://api.github.com/users/ramprakashram/repos',
#        'events_url': 'https://api.github.com/users/ramprakashram/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ramprakashram/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ramprakashram/child-cam',
#       'description': 'A camera application focussed on fun-filled UI for children using Ionic Framework',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ramprakashram/child-cam',
#       'forks_url': 'https://api.github.com/repos/ramprakashram/child-cam/forks',
#       'keys_url': 'https://api.github.com/repos/ramprakashram/child-cam/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ramprakashram/child-cam/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ramprakashram/child-cam/teams',
#       'hooks_url': 'https://api.github.com/repos/ramprakashram/child-cam/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ramprakashram/child-cam/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ramprakashram/child-cam/events',
#       'assignees_url': 'https://api.github.com/repos/ramprakashram/child-cam/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ramprakashram/child-cam/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ramprakashram/child-cam/tags',
#       'blobs_url': 'https://api.github.com/repos/ramprakashram/child-cam/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ramprakashram/child-cam/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ramprakashram/child-cam/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ramprakashram/child-cam/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ramprakashram/child-cam/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ramprakashram/child-cam/languages',
#       'stargazers_url': 'https://api.github.com/repos/ramprakashram/child-cam/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ramprakashram/child-cam/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ramprakashram/child-cam/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ramprakashram/child-cam/subscription',
#       'commits_url': 'https://api.github.com/repos/ramprakashram/child-cam/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ramprakashram/child-cam/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ramprakashram/child-cam/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ramprakashram/child-cam/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ramprakashram/child-cam/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ramprakashram/child-cam/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ramprakashram/child-cam/merges',
#       'archive_url': 'https://api.github.com/repos/ramprakashram/child-cam/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ramprakashram/child-cam/downloads',
#       'issues_url': 'https://api.github.com/repos/ramprakashram/child-cam/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ramprakashram/child-cam/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ramprakashram/child-cam/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ramprakashram/child-cam/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ramprakashram/child-cam/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ramprakashram/child-cam/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ramprakashram/child-cam/deployments',
#       'created_at': '2019-11-09T12:34:45Z',
#       'updated_at': '2022-02-16T09:34:25Z',
#       'pushed_at': '2022-02-16T09:35:38Z',
#       'git_url': 'git://github.com/ramprakashram/child-cam.git',
#       'ssh_url': 'git@github.com:ramprakashram/child-cam.git',
#       'clone_url': 'https://github.com/ramprakashram/child-cam.git',
#       'svn_url': 'https://github.com/ramprakashram/child-cam',
#       'homepage': None,
#       'size': 3958,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 16,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 16,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ramprakashram/child-cam/pulls/4'},
#      'html': {'href': 'https://github.com/ramprakashram/child-cam/pull/4'},
#      'issue': {'href': 'https://api.github.com/repos/ramprakashram/child-cam/issues/4'},
#      'comments': {'href': 'https://api.github.com/repos/ramprakashram/child-cam/issues/4/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ramprakashram/child-cam/pulls/4/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ramprakashram/child-cam/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ramprakashram/child-cam/pulls/4/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ramprakashram/child-cam/statuses/b244bf841b6adf79a7336ad5583a9f156b98d2a4'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'ramprakashram',
#      'id': 31797738,
#      'node_id': 'MDQ6VXNlcjMxNzk3NzM4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/31797738?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ramprakashram',
#      'html_url': 'https://github.com/ramprakashram',
#      'followers_url': 'https://api.github.com/users/ramprakashram/followers',
#      'following_url': 'https://api.github.com/users/ramprakashram/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ramprakashram/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ramprakashram/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ramprakashram/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ramprakashram/orgs',
#      'repos_url': 'https://api.github.com/users/ramprakashram/repos',
#      'events_url': 'https://api.github.com/users/ramprakashram/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ramprakashram/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 71,
#     'deletions': 22,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2022-02-16T09:35:39Z'}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                           type  \
# 0   20285068578                    CreateEvent
# 1   20285068574  PullRequestReviewCommentEvent
# 2   20285068601                      ForkEvent
# 3   20285068583                    CreateEvent
# 4   20285068591                      PushEvent
# 5   20285068577                    CreateEvent
# 6   20285068575                      PushEvent
# 7   20285068559                      PushEvent
# 8   20285068582                    CreateEvent
# 9   20285068529                    CreateEvent
# 10  20285068565               PullRequestEvent
# 11  20285068501                      PushEvent
# 12  20285068532                      PushEvent
# 13  20285068493                      PushEvent
# 14  20285068533                      PushEvent
# 15  20285068480                      PushEvent
# 16  20285068499                      PushEvent
# 17  20285068517         PullRequestReviewEvent
# 18  20285068484                      PushEvent
# 19  20285068504              IssueCommentEvent
# 20  20285068437                      PushEvent
# 21  20285068464              IssueCommentEvent
# 22  20285068460                    CreateEvent
# 23  20285068458                    DeleteEvent
# 24  20285068451  PullRequestReviewCommentEvent
# 25  20285068426                      PushEvent
# 26  20285068409                      PushEvent
# 27  20285068449  PullRequestReviewCommentEvent
# 28  20285068446  PullRequestReviewCommentEvent
# 29  20285068440               PullRequestEvent
#
#                                                 actor  \
# 0   {'id': 52290251, 'login': 'botcopado', 'displa...
# 1   {'id': 91113035, 'login': 'DmitriyLewen', 'dis...
# 2   {'id': 84758240, 'login': 'aliang-bigdata', 'd...
# 3   {'id': 99338701, 'login': 'LidiaMoreno', 'disp...
# 4   {'id': 99035456, 'login': 'prasanthgoli', 'dis...
# 5   {'id': 52290251, 'login': 'botcopado', 'displa...
# 6   {'id': 5656720, 'login': 'dyakovri', 'display_...
# 7   {'id': 43138394, 'login': 'mrasw', 'display_lo...
# 8   {'id': 86326137, 'login': 'bot-monkey-7', 'dis...
# 9   {'id': 79044155, 'login': 'himdrakibulislam', ...
# 10  {'id': 29139614, 'login': 'renovate[bot]', 'di...
# 11  {'id': 2687598, 'login': 'milesholt', 'display...
# 12  {'id': 57421193, 'login': 'joshua-simon', 'dis...
# 13  {'id': 694745, 'login': 'rmayr', 'display_logi...
# 14  {'id': 8605538, 'login': 'zhiqiuyao', 'display...
# 15  {'id': 2650046, 'login': 'jdciorraga', 'displa...
# 16  {'id': 99140454, 'login': 'apertureinnovations...
# 17  {'id': 91113035, 'login': 'DmitriyLewen', 'dis...
# 18  {'id': 52518050, 'login': 'SciGEsN', 'display_...
# 19  {'id': 10911965, 'login': 'dotneft', 'display_...
# 20  {'id': 91558355, 'login': 'Ficsur12345', 'disp...
# 21  {'id': 13497697, 'login': 'ShahinSorkh', 'disp...
# 22  {'id': 46190291, 'login': 'Babuuh', 'display_l...
# 23  {'id': 10810283, 'login': 'direwolf-github', '...
# 24  {'id': 9059541, 'login': 'seladb', 'display_lo...
# 25  {'id': 41898282, 'login': 'github-actions[bot]...
# 26  {'id': 99376023, 'login': 'mzkkomatsu', 'displ...
# 27  {'id': 9059541, 'login': 'seladb', 'display_lo...
# 28  {'id': 9059541, 'login': 'seladb', 'display_lo...
# 29  {'id': 31797738, 'login': 'ramprakashram', 'di...
#
#                                                  repo  \
# 0   {'id': 459937563, 'name': 'botcopado/moeldv_BS...
# 1   {'id': 75539205, 'name': 'aquasecurity/postee'...
# 2   {'id': 364195197, 'name': 'findify/featury', '...
# 3   {'id': 459937671, 'name': 'LidiaMoreno/Solucio...
# 4   {'id': 458164143, 'name': 'prasanthgoli/my-ans...
# 5   {'id': 459937550, 'name': 'botcopado/moeldv_GM...
# 6   {'id': 433204426, 'name': 'profcomff/data-pipe...
# 7   {'id': 459923433, 'name': 'mrasw/ChiefAGRO', '...
# 8   {'id': 356421872, 'name': 'test-organization-k...
# 9   {'id': 459937669, 'name': 'himdrakibulislam/Ed...
# 10  {'id': 422531348, 'name': 'choice-form/mono-ap...
# 11  {'id': 247480564, 'name': 'milesholt/autotrade...
# 12  {'id': 456376170, 'name': 'joshua-simon/welly-...
# 13  {'id': 436041382, 'name': 'rmayr/mhutchinson-d...
# 14  {'id': 254461076, 'name': 'zhiqiuyao/zhiqiuyao...
# 15  {'id': 459922358, 'name': 'jdciorraga/pruebasi...
# 16  {'id': 458656351, 'name': 'apertureinnovations...
# 17  {'id': 75539205, 'name': 'aquasecurity/postee'...
# 18  {'id': 457589675, 'name': 'SciGEsN/SRC086', 'u...
# 19  {'id': 64825667, 'name': 'zabbix/zabbix-docker...
# 20  {'id': 411399267, 'name': 'Ficsur12345/kollazs...
# 21  {'id': 279718268, 'name': 'BaseMax/BaseMax', '...
# 22  {'id': 459937668, 'name': 'Babuuh/alx-pre_cour...
# 23  {'id': 459937502, 'name': 'direwolf-github/eph...
# 24  {'id': 24911519, 'name': 'seladb/PcapPlusPlus'...
# 25  {'id': 445250338, 'name': 'Rameliaa/-2', 'url'...
# 26  {'id': 459909195, 'name': 'mzkkomatsu/mzkkomat...
# 27  {'id': 24911519, 'name': 'seladb/PcapPlusPlus'...
# 28  {'id': 24911519, 'name': 'seladb/PcapPlusPlus'...
# 29  {'id': 220639687, 'name': 'ramprakashram/child...
#
#                                               payload  public  \
# 0   {'ref': 'master', 'ref_type': 'branch', 'maste...    True
# 1   {'action': 'created', 'comment': {'url': 'http...    True
# 2   {'forkee': {'id': 459937672, 'node_id': 'R_kgD...    True
# 3   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 4   {'push_id': 9116270265, 'size': 1, 'distinct_s...    True
# 5   {'ref': 'master', 'ref_type': 'branch', 'maste...    True
# 6   {'push_id': 9116270262, 'size': 5, 'distinct_s...    True
# 7   {'push_id': 9116270263, 'size': 1, 'distinct_s...    True
# 8   {'ref': 'monkey-branch-d8yy7n', 'ref_type': 'b...    True
# 9   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 10  {'action': 'closed', 'number': 439, 'pull_requ...    True
# 11  {'push_id': 9116270235, 'size': 1, 'distinct_s...    True
# 12  {'push_id': 9116270244, 'size': 1, 'distinct_s...    True
# 13  {'push_id': 9116270228, 'size': 7, 'distinct_s...    True
# 14  {'push_id': 9116270241, 'size': 1, 'distinct_s...    True
# 15  {'push_id': 9116270225, 'size': 1, 'distinct_s...    True
# 16  {'push_id': 9116270233, 'size': 1, 'distinct_s...    True
# 17  {'action': 'created', 'review': {'id': 8842168...    True
# 18  {'push_id': 9116270212, 'size': 1, 'distinct_s...    True
# 19  {'action': 'created', 'issue': {'url': 'https:...    True
# 20  {'push_id': 9116270202, 'size': 1, 'distinct_s...    True
# 21  {'action': 'created', 'issue': {'url': 'https:...    True
# 22  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 23  {'ref': 'branch-75de44f6', 'ref_type': 'branch...    True
# 24  {'action': 'created', 'comment': {'url': 'http...    True
# 25  {'push_id': 9116270180, 'size': 1, 'distinct_s...    True
# 26  {'push_id': 9116270177, 'size': 1, 'distinct_s...    True
# 27  {'action': 'created', 'comment': {'url': 'http...    True
# 28  {'action': 'created', 'comment': {'url': 'http...    True
# 29  {'action': 'closed', 'number': 4, 'pull_reques...    True
#
#               created_at                                                org
# 0   2022-02-16T09:35:39Z                                                NaN
# 1   2022-02-16T09:35:39Z  {'id': 12783832, 'login': 'aquasecurity', 'gra...
# 2   2022-02-16T09:35:39Z  {'id': 5618622, 'login': 'findify', 'gravatar_...
# 3   2022-02-16T09:35:39Z                                                NaN
# 4   2022-02-16T09:35:39Z                                                NaN
# 5   2022-02-16T09:35:39Z                                                NaN
# 6   2022-02-16T09:35:39Z  {'id': 94626404, 'login': 'profcomff', 'gravat...
# 7   2022-02-16T09:35:39Z                                                NaN
# 8   2022-02-16T09:35:39Z  {'id': 47997193, 'login': 'test-organization-k...
# 9   2022-02-16T09:35:39Z                                                NaN
# 10  2022-02-16T09:35:39Z  {'id': 12053581, 'login': 'choice-form', 'grav...
# 11  2022-02-16T09:35:39Z                                                NaN
# 12  2022-02-16T09:35:39Z                                                NaN
# 13  2022-02-16T09:35:39Z                                                NaN
# 14  2022-02-16T09:35:39Z                                                NaN
# 15  2022-02-16T09:35:39Z                                                NaN
# 16  2022-02-16T09:35:39Z                                                NaN
# 17  2022-02-16T09:35:39Z  {'id': 12783832, 'login': 'aquasecurity', 'gra...
# 18  2022-02-16T09:35:39Z                                                NaN
# 19  2022-02-16T09:35:39Z  {'id': 4561226, 'login': 'zabbix', 'gravatar_i...
# 20  2022-02-16T09:35:39Z                                                NaN
# 21  2022-02-16T09:35:39Z                                                NaN
# 22  2022-02-16T09:35:39Z                                                NaN
# 23  2022-02-16T09:35:39Z                                                NaN
# 24  2022-02-16T09:34:15Z                                                NaN
# 25  2022-02-16T09:35:39Z                                                NaN
# 26  2022-02-16T09:35:39Z                                                NaN
# 27  2022-02-16T09:33:13Z                                                NaN
# 28  2022-02-16T09:33:01Z                                                NaN
# 29  2022-02-16T09:35:39Z                                                NaN

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id                           type  public            created_at  \
# 0   20285068578                    CreateEvent    True  2022-02-16T09:35:39Z
# 1   20285068574  PullRequestReviewCommentEvent    True  2022-02-16T09:35:39Z
# 2   20285068601                      ForkEvent    True  2022-02-16T09:35:39Z
# 3   20285068583                    CreateEvent    True  2022-02-16T09:35:39Z
# 4   20285068591                      PushEvent    True  2022-02-16T09:35:39Z
# 5   20285068577                    CreateEvent    True  2022-02-16T09:35:39Z
# 6   20285068575                      PushEvent    True  2022-02-16T09:35:39Z
# 7   20285068559                      PushEvent    True  2022-02-16T09:35:39Z
# 8   20285068582                    CreateEvent    True  2022-02-16T09:35:39Z
# 9   20285068529                    CreateEvent    True  2022-02-16T09:35:39Z
# 10  20285068565               PullRequestEvent    True  2022-02-16T09:35:39Z
# 11  20285068501                      PushEvent    True  2022-02-16T09:35:39Z
# 12  20285068532                      PushEvent    True  2022-02-16T09:35:39Z
# 13  20285068493                      PushEvent    True  2022-02-16T09:35:39Z
# 14  20285068533                      PushEvent    True  2022-02-16T09:35:39Z
# 15  20285068480                      PushEvent    True  2022-02-16T09:35:39Z
# 16  20285068499                      PushEvent    True  2022-02-16T09:35:39Z
# 17  20285068517         PullRequestReviewEvent    True  2022-02-16T09:35:39Z
# 18  20285068484                      PushEvent    True  2022-02-16T09:35:39Z
# 19  20285068504              IssueCommentEvent    True  2022-02-16T09:35:39Z
# 20  20285068437                      PushEvent    True  2022-02-16T09:35:39Z
# 21  20285068464              IssueCommentEvent    True  2022-02-16T09:35:39Z
# 22  20285068460                    CreateEvent    True  2022-02-16T09:35:39Z
# 23  20285068458                    DeleteEvent    True  2022-02-16T09:35:39Z
# 24  20285068451  PullRequestReviewCommentEvent    True  2022-02-16T09:34:15Z
# 25  20285068426                      PushEvent    True  2022-02-16T09:35:39Z
# 26  20285068409                      PushEvent    True  2022-02-16T09:35:39Z
# 27  20285068449  PullRequestReviewCommentEvent    True  2022-02-16T09:33:13Z
# 28  20285068446  PullRequestReviewCommentEvent    True  2022-02-16T09:33:01Z
# 29  20285068440               PullRequestEvent    True  2022-02-16T09:35:39Z
#
#     actor.id          actor.login  actor.display_login actor.gravatar_id  \
# 0   52290251            botcopado            botcopado
# 1   91113035         DmitriyLewen         DmitriyLewen
# 2   84758240       aliang-bigdata       aliang-bigdata
# 3   99338701          LidiaMoreno          LidiaMoreno
# 4   99035456         prasanthgoli         prasanthgoli
# 5   52290251            botcopado            botcopado
# 6    5656720             dyakovri             dyakovri
# 7   43138394                mrasw                mrasw
# 8   86326137         bot-monkey-7         bot-monkey-7
# 9   79044155     himdrakibulislam     himdrakibulislam
# 10  29139614        renovate[bot]             renovate
# 11   2687598            milesholt            milesholt
# 12  57421193         joshua-simon         joshua-simon
# 13    694745                rmayr                rmayr
# 14   8605538            zhiqiuyao            zhiqiuyao
# 15   2650046           jdciorraga           jdciorraga
# 16  99140454  apertureinnovations  apertureinnovations
# 17  91113035         DmitriyLewen         DmitriyLewen
# 18  52518050              SciGEsN              SciGEsN
# 19  10911965              dotneft              dotneft
# 20  91558355          Ficsur12345          Ficsur12345
# 21  13497697          ShahinSorkh          ShahinSorkh
# 22  46190291               Babuuh               Babuuh
# 23  10810283      direwolf-github      direwolf-github
# 24   9059541               seladb               seladb
# 25  41898282  github-actions[bot]       github-actions
# 26  99376023           mzkkomatsu           mzkkomatsu
# 27   9059541               seladb               seladb
# 28   9059541               seladb               seladb
# 29  31797738        ramprakashram        ramprakashram
#
#                                            actor.url  \
# 0             https://api.github.com/users/botcopado
# 1          https://api.github.com/users/DmitriyLewen
# 2        https://api.github.com/users/aliang-bigdata
# 3           https://api.github.com/users/LidiaMoreno
# 4          https://api.github.com/users/prasanthgoli
# 5             https://api.github.com/users/botcopado
# 6              https://api.github.com/users/dyakovri
# 7                 https://api.github.com/users/mrasw
# 8          https://api.github.com/users/bot-monkey-7
# 9      https://api.github.com/users/himdrakibulislam
# 10        https://api.github.com/users/renovate[bot]
# 11            https://api.github.com/users/milesholt
# 12         https://api.github.com/users/joshua-simon
# 13                https://api.github.com/users/rmayr
# 14            https://api.github.com/users/zhiqiuyao
# 15           https://api.github.com/users/jdciorraga
# 16  https://api.github.com/users/apertureinnovations
# 17         https://api.github.com/users/DmitriyLewen
# 18              https://api.github.com/users/SciGEsN
# 19              https://api.github.com/users/dotneft
# 20          https://api.github.com/users/Ficsur12345
# 21          https://api.github.com/users/ShahinSorkh
# 22               https://api.github.com/users/Babuuh
# 23      https://api.github.com/users/direwolf-github
# 24               https://api.github.com/users/seladb
# 25  https://api.github.com/users/github-actions[bot]
# 26           https://api.github.com/users/mzkkomatsu
# 27               https://api.github.com/users/seladb
# 28               https://api.github.com/users/seladb
# 29        https://api.github.com/users/ramprakashram
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/52290251?  ...
# 1   https://avatars.githubusercontent.com/u/91113035?  ...
# 2   https://avatars.githubusercontent.com/u/84758240?  ...
# 3   https://avatars.githubusercontent.com/u/99338701?  ...
# 4   https://avatars.githubusercontent.com/u/99035456?  ...
# 5   https://avatars.githubusercontent.com/u/52290251?  ...
# 6    https://avatars.githubusercontent.com/u/5656720?  ...
# 7   https://avatars.githubusercontent.com/u/43138394?  ...
# 8   https://avatars.githubusercontent.com/u/86326137?  ...
# 9   https://avatars.githubusercontent.com/u/79044155?  ...
# 10  https://avatars.githubusercontent.com/u/29139614?  ...
# 11   https://avatars.githubusercontent.com/u/2687598?  ...
# 12  https://avatars.githubusercontent.com/u/57421193?  ...
# 13    https://avatars.githubusercontent.com/u/694745?  ...
# 14   https://avatars.githubusercontent.com/u/8605538?  ...
# 15   https://avatars.githubusercontent.com/u/2650046?  ...
# 16  https://avatars.githubusercontent.com/u/99140454?  ...
# 17  https://avatars.githubusercontent.com/u/91113035?  ...
# 18  https://avatars.githubusercontent.com/u/52518050?  ...
# 19  https://avatars.githubusercontent.com/u/10911965?  ...
# 20  https://avatars.githubusercontent.com/u/91558355?  ...
# 21  https://avatars.githubusercontent.com/u/13497697?  ...
# 22  https://avatars.githubusercontent.com/u/46190291?  ...
# 23  https://avatars.githubusercontent.com/u/10810283?  ...
# 24   https://avatars.githubusercontent.com/u/9059541?  ...
# 25  https://avatars.githubusercontent.com/u/41898282?  ...
# 26  https://avatars.githubusercontent.com/u/99376023?  ...
# 27   https://avatars.githubusercontent.com/u/9059541?  ...
# 28   https://avatars.githubusercontent.com/u/9059541?  ...
# 29  https://avatars.githubusercontent.com/u/31797738?  ...
#
#                  payload.issue.assignee.following_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  https://api.github.com/users/BaseMax/following...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                      payload.issue.assignee.gists_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  https://api.github.com/users/BaseMax/gists{/gi...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                    payload.issue.assignee.starred_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  https://api.github.com/users/BaseMax/starred{/...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#              payload.issue.assignee.subscriptions_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  https://api.github.com/users/BaseMax/subscript...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#      payload.issue.assignee.organizations_url  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21  https://api.github.com/users/BaseMax/orgs
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
#
#               payload.issue.assignee.repos_url  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21  https://api.github.com/users/BaseMax/repos
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
#
#                     payload.issue.assignee.events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  https://api.github.com/users/BaseMax/events{/p...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#            payload.issue.assignee.received_events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  https://api.github.com/users/BaseMax/received_...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#    payload.issue.assignee.type payload.issue.assignee.site_admin
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
# 5                          NaN                               NaN
# 6                          NaN                               NaN
# 7                          NaN                               NaN
# 8                          NaN                               NaN
# 9                          NaN                               NaN
# 10                         NaN                               NaN
# 11                         NaN                               NaN
# 12                         NaN                               NaN
# 13                         NaN                               NaN
# 14                         NaN                               NaN
# 15                         NaN                               NaN
# 16                         NaN                               NaN
# 17                         NaN                               NaN
# 18                         NaN                               NaN
# 19                         NaN                               NaN
# 20                         NaN                               NaN
# 21                        User                             False
# 22                         NaN                               NaN
# 23                         NaN                               NaN
# 24                         NaN                               NaN
# 25                         NaN                               NaN
# 26                         NaN                               NaN
# 27                         NaN                               NaN
# 28                         NaN                               NaN
# 29                         NaN                               NaN
#
# [30 rows x 613 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'iss_position': {'latitude': '9.2126', 'longitude': '-71.4863'},
#  'timestamp': 1645004929}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"lat": 52.53370520371973, "lon": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312'

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1645005147,
#   'latitude': 52.53370520371973,
#   'longitude': 13.453475292072312,
#   'passes': 5},
#  'response': [{'duration': 651, 'risetime': 1645005884},
#   {'duration': 629, 'risetime': 1645011687},
#   {'duration': 491, 'risetime': 1645017515},
#   {'duration': 101, 'risetime': 1645072364},
#   {'duration': 571, 'risetime': 1645077861}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1645005884)
# Out:
# datetime.datetime(2022, 2, 16, 11, 4, 44)

# %%
pd.to_datetime(1637772367, unit="s")
# Out:
# Timestamp('2021-11-24 16:46:07')

# %% [markdown]
# ### Weather API
#
# Create an account at RapidAPI and "subscribe" to the Weather API: https://rapidapi.com/weatherbit/api/

# %%
import requests

## https://rapidapi.com/community/api/open-weather-map/
url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

#My location coords: lat: 40.545111, lon: -4.204942
querystring = {"lon":"-4.204942","lat":"40.545111"}
querystring["units"] ="metric"
querystring["lang"] = "en"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gh/s8b9pd096y13z1bxsq63d0x40000gn/T/ipykernel_33898/494424325.py in <module>
#      10
#      11 headers = {
# ---> 12     'x-rapidapi-key': x_rapidapi_key,
#      13     'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
#      14     }
#
# NameError: name 'x_rapidapi_key' is not defined

# %%
results = response.json()
print(results)
type(results)
# Out:
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1644965430, 'latitude': 52.53370520371973, 'longitude': 13.453475292072312, 'passes': 5}, 'response': [{'duration': 350, 'risetime': 1644988708}, {'duration': 603, 'risetime': 1644994325}, {'duration': 649, 'risetime': 1645000084}, {'duration': 651, 'risetime': 1645005884}, {'duration': 629, 'risetime': 1645011686}]}
# dict

# %%
results.keys()
# Out:
# dict_keys(['message', 'request', 'response'])

# %% [markdown]
# Getting the forecast for the next 5 days at a 3h intervals

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
print(results)
# Out:
# {'data': [{'wind_cdir': 'ENE', 'rh': 39, 'pod': 'd', 'timestamp_utc': '2021-06-15T09:00:00', 'pres': 884.145, 'solar_rad': 564.782, 'ozone': 336, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 11.5571, 'timestamp_local': '2021-06-15T11:00:00', 'snow_depth': 0, 'clouds': 69, 'ts': 1623747600, 'wind_spd': 4.07371, 'pop': 15, 'wind_cdir_full': 'east-northeast', 'slp': 1018.79, 'dni': 868.79, 'dewpt': 7.9, 'snow': 0, 'uv': 2.81755, 'wind_dir': 78, 'clouds_hi': 0, 'precip': 0.001953125, 'vis': 24.128, 'dhi': 103.41, 'app_temp': 22.4, 'datetime': '2021-06-15:09', 'temp': 23, 'ghi': 717.09, 'clouds_mid': 69, 'clouds_low': 0}, {'wind_cdir': 'ESE', 'rh': 27, 'pod': 'd', 'timestamp_utc': '2021-06-15T12:00:00', 'pres': 883.112, 'solar_rad': 974.853, 'ozone': 328, 'weather': {'icon': 'c02d', 'code': 801, 'description': 'Few clouds'}, 'wind_gust_spd': 11.7118, 'timestamp_local': '2021-06-15T14:00:00', 'snow_depth': 0, 'clouds': 38, 'ts': 1623758400, 'wind_spd': 5.50618, 'pop': 0, 'wind_cdir_full': 'east-southeast', 'slp': 1016.89, 'dni': 937.94, 'dewpt': 6, 'snow': 0, 'uv': 7.58151, 'wind_dir': 111, 'clouds_hi': 2, 'precip': 0, 'vis': 24.128, 'dhi': 117.62, 'app_temp': 26.2, 'datetime': '2021-06-15:12', 'temp': 26.8, 'ghi': 1002.88, 'clouds_mid': 39, 'clouds_low': 0}, {'wind_cdir': 'SSE', 'rh': 24, 'pod': 'd', 'timestamp_utc': '2021-06-15T15:00:00', 'pres': 881.339, 'solar_rad': 565.139, 'ozone': 323, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 12.2921, 'timestamp_local': '2021-06-15T17:00:00', 'snow_depth': 0, 'clouds': 76, 'ts': 1623769200, 'wind_spd': 4.28592, 'pop': 15, 'wind_cdir_full': 'south-southeast', 'slp': 1014.46, 'dni': 892.15, 'dewpt': 5.4, 'snow': 0, 'uv': 3.15302, 'wind_dir': 164, 'clouds_hi': 43, 'precip': 0.048828125, 'vis': 24.128, 'dhi': 107.98, 'app_temp': 26.9, 'datetime': '2021-06-15:15', 'temp': 28.1, 'ghi': 801.62, 'clouds_mid': 56, 'clouds_low': 0}, {'wind_cdir': 'S', 'rh': 28, 'pod': 'd', 'timestamp_utc': '2021-06-15T18:00:00', 'pres': 880.719, 'solar_rad': 170.431, 'ozone': 320.5, 'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 10.1157, 'timestamp_local': '2021-06-15T20:00:00', 'snow_depth': 0, 'clouds': 80, 'ts': 1623780000, 'wind_spd': 4.75035, 'pop': 15, 'wind_cdir_full': 'south', 'slp': 1013.91, 'dni': 647.18, 'dewpt': 6, 'snow': 0, 'uv': 0.813903, 'wind_dir': 169, 'clouds_hi': 12, 'precip': 0.021484375, 'vis': 19.2, 'dhi': 68.69, 'app_temp': 25.8, 'datetime': '2021-06-15:18', 'temp': 26.4, 'ghi': 262.69, 'clouds_mid': 78, 'clouds_low': 0}, {'wind_cdir': 'NE', 'rh': 48, 'pod': 'n', 'timestamp_utc': '2021-06-15T21:00:00', 'pres': 881.045, 'solar_rad': 0, 'ozone': 319, 'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 7.37562, 'timestamp_local': '2021-06-15T23:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623790800, 'wind_spd': 2.08412, 'pop': 10, 'wind_cdir_full': 'northeast', 'slp': 1015.38, 'dni': 0, 'dewpt': 9.5, 'snow': 0, 'uv': 0, 'wind_dir': 48, 'clouds_hi': 100, 'precip': 0.095703125, 'vis': 24.128, 'dhi': 0, 'app_temp': 20.8, 'datetime': '2021-06-15:21', 'temp': 21.4, 'ghi': 0, 'clouds_mid': 81, 'clouds_low': 8}, {'wind_cdir': 'E', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T00:00:00', 'pres': 881.915, 'solar_rad': 0, 'ozone': 324.75, 'weather': {'icon': 'r04n', 'code': 520, 'description': 'Light shower rain'}, 'wind_gust_spd': 9.4193, 'timestamp_local': '2021-06-16T02:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623801600, 'wind_spd': 1.0167, 'pop': 25, 'wind_cdir_full': 'east', 'slp': 1017.05, 'dni': 0, 'dewpt': 11.9, 'snow': 0, 'uv': 0, 'wind_dir': 90, 'clouds_hi': 100, 'precip': 0.33984375, 'vis': 24.128, 'dhi': 0, 'app_temp': 18.1, 'datetime': '2021-06-16:00', 'temp': 18.4, 'ghi': 0, 'clouds_mid': 70, 'clouds_low': 4}, {'wind_cdir': 'ENE', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T03:00:00', 'pre ...
