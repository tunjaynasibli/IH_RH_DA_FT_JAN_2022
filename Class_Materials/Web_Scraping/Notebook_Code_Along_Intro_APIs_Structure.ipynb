# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
import pandas as pd
# json to pandas dataframe

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '20277534561',
#   'type': 'PushEvent',
#   'actor': {'id': 13855126,
#    'login': 'marek-hanzal',
#    'display_login': 'marek-hanzal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marek-hanzal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13855126?'},
#   'repo': {'id': 394701910,
#    'name': 'marek-hanzal/puff-smith',
#    'url': 'https://api.github.com/repos/marek-hanzal/puff-smith'},
#   'payload': {'push_id': 9112476198,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '060ad2240c592ec0f7cc2047ac6ee49a18825669',
#    'before': '980348e53ae69a7aafbdbd204d22aa36df905f5e',
#    'commits': [{'sha': '060ad2240c592ec0f7cc2047ac6ee49a18825669',
#      'author': {'email': 'marek.hanzal@x32.cz', 'name': 'Marek Hanzal'},
#      'message': 'Common: Added support for voltage on mod',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/marek-hanzal/puff-smith/commits/060ad2240c592ec0f7cc2047ac6ee49a18825669'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534579',
#   'type': 'PushEvent',
#   'actor': {'id': 89932011,
#    'login': 'raiderpls',
#    'display_login': 'raiderpls',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/raiderpls',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89932011?'},
#   'repo': {'id': 458976759,
#    'name': 'raiderpls/tiny-format',
#    'url': 'https://api.github.com/repos/raiderpls/tiny-format'},
#   'payload': {'push_id': 9112476203,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6206d38d7249d1f1bbc2be5d9cdcc6663595fe80',
#    'before': '2e93923298862e7e32636b8b9b10e62f0f772d54',
#    'commits': [{'sha': '6206d38d7249d1f1bbc2be5d9cdcc6663595fe80',
#      'author': {'email': '89932011+raiderpls@users.noreply.github.com',
#       'name': 'raiderpls'},
#      'message': 'Update c74374769.lua',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/raiderpls/tiny-format/commits/6206d38d7249d1f1bbc2be5d9cdcc6663595fe80'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534571',
#   'type': 'PushEvent',
#   'actor': {'id': 2334215,
#    'login': 'suluke',
#    'display_login': 'suluke',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/suluke',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2334215?'},
#   'repo': {'id': 423557122,
#    'name': 'suluke/ultrustar',
#    'url': 'https://api.github.com/repos/suluke/ultrustar'},
#   'payload': {'push_id': 9112476213,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '519efcb312774c97cee5e349e42b4fbc2b38db4e',
#    'before': 'feef9a5696c6541fae3a01c602a3af4623b9d4fd',
#    'commits': [{'sha': '519efcb312774c97cee5e349e42b4fbc2b38db4e',
#      'author': {'email': 'suluke93@gmail.com', 'name': 'Lukas Böhm'},
#      'message': "Write some audio code\n\nCurrent idea is to return from the audio callback as quickly as possible\nby memcopying into one of 2 vecs (allocations) which are rotating\nthrough a 2-element-wide bounded channel. This allows both the producing\nside as well as the receiving side to take ownership of a location at\nany given time. At the same time, the channel guarantees that the\nproducer always overwrites the oldest data (ordering guarantee). The\ndrawback is that the receiver may only get the second-newest sample\nbuffer. I'll probably need to think about this a bit more...",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/suluke/ultrustar/commits/519efcb312774c97cee5e349e42b4fbc2b38db4e'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534555',
#   'type': 'CreateEvent',
#   'actor': {'id': 62577524,
#    'login': 'tan14142',
#    'display_login': 'tan14142',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tan14142',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/62577524?'},
#   'repo': {'id': 459774024,
#    'name': 'tan14142/wordle',
#    'url': 'https://api.github.com/repos/tan14142/wordle'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Wordle clone',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534572',
#   'type': 'CreateEvent',
#   'actor': {'id': 33194722,
#    'login': '1elirantoledano',
#    'display_login': '1elirantoledano',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/1elirantoledano',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33194722?'},
#   'repo': {'id': 459748702,
#    'name': '1elirantoledano/ShopLifters',
#    'url': 'https://api.github.com/repos/1elirantoledano/ShopLifters'},
#   'payload': {'ref': 'dev',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Android app for shopping list',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534529',
#   'type': 'PushEvent',
#   'actor': {'id': 77168453,
#    'login': 'kimjensen-hpe',
#    'display_login': 'kimjensen-hpe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kimjensen-hpe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77168453?'},
#   'repo': {'id': 386357982,
#    'name': 'Cray-HPE/csm-testing',
#    'url': 'https://api.github.com/repos/Cray-HPE/csm-testing'},
#   'payload': {'push_id': 9112476189,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/CASMINST-4030-1.2',
#    'head': '9356d1e833ea7bdc80ec66b4506cf27ef1eb5e77',
#    'before': 'ac0794d099e2c3a53f23649ec51863330df8f9fb',
#    'commits': [{'sha': '9356d1e833ea7bdc80ec66b4506cf27ef1eb5e77',
#      'author': {'email': 'kim.jensen@hpe.com', 'name': 'kimjensen-hpe'},
#      'message': 'CASMINST-4030 1.2 : TESTS - Kubernetes Postgresql Check that Automated Backups are Working',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Cray-HPE/csm-testing/commits/9356d1e833ea7bdc80ec66b4506cf27ef1eb5e77'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z',
#   'org': {'id': 74066787,
#    'login': 'Cray-HPE',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Cray-HPE',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74066787?'}},
#  {'id': '20277534537',
#   'type': 'PushEvent',
#   'actor': {'id': 56883295,
#    'login': 'marcospfduarte',
#    'display_login': 'marcospfduarte',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marcospfduarte',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56883295?'},
#   'repo': {'id': 459746516,
#    'name': 'mfranciscao/ciencia_de_dados',
#    'url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados'},
#   'payload': {'push_id': 9112476201,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'dd2e659f50f19ae2d053f5dbc0e460dd8e306aeb',
#    'before': '8059c550625f6e834cdf5b03d578336556d8d4e1',
#    'commits': [{'sha': '483058dd094e555fd350295486aeb17b3f1fe4e4',
#      'author': {'email': 'matheusrobertofranciscao@gmail.com',
#       'name': 'Matheus Franciscão'},
#      'message': 'Adição do código com webscrapping',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/commits/483058dd094e555fd350295486aeb17b3f1fe4e4'},
#     {'sha': 'dd2e659f50f19ae2d053f5dbc0e460dd8e306aeb',
#      'author': {'email': '56883295+marcospfduarte@users.noreply.github.com',
#       'name': 'Marcos P F duarte'},
#      'message': 'Merge pull request #8 from mfranciscao/ideia_scrapping\n\nAdição do código com webscrapping',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/commits/dd2e659f50f19ae2d053f5dbc0e460dd8e306aeb'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534550',
#   'type': 'PushEvent',
#   'actor': {'id': 13355009,
#    'login': 'AgentOxygen',
#    'display_login': 'AgentOxygen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AgentOxygen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13355009?'},
#   'repo': {'id': 445943421,
#    'name': 'AgentOxygen/java_games',
#    'url': 'https://api.github.com/repos/AgentOxygen/java_games'},
#   'payload': {'push_id': 9112476192,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b688bde8d3848a8c5bb0343ba8357478d65cb8a0',
#    'before': 'ba377332806aa2a340030a10dd36020dea22243f',
#    'commits': [{'sha': 'b688bde8d3848a8c5bb0343ba8357478d65cb8a0',
#      'author': {'email': 'cameronscummins@gmail.com', 'name': 'AgentOxygen'},
#      'message': 'Added dust project',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/AgentOxygen/java_games/commits/b688bde8d3848a8c5bb0343ba8357478d65cb8a0'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534522',
#   'type': 'ForkEvent',
#   'actor': {'id': 75698082,
#    'login': 'IsaquePinkuss',
#    'display_login': 'IsaquePinkuss',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IsaquePinkuss',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/75698082?'},
#   'repo': {'id': 59958668,
#    'name': 'da2k/curso-reactjs-ninja',
#    'url': 'https://api.github.com/repos/da2k/curso-reactjs-ninja'},
#   'payload': {'forkee': {'id': 459774023,
#     'node_id': 'R_kgDOG2eYRw',
#     'name': 'curso-reactjs-ninja',
#     'full_name': 'IsaquePinkuss/curso-reactjs-ninja',
#     'private': False,
#     'owner': {'login': 'IsaquePinkuss',
#      'id': 75698082,
#      'node_id': 'MDQ6VXNlcjc1Njk4MDgy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/75698082?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/IsaquePinkuss',
#      'html_url': 'https://github.com/IsaquePinkuss',
#      'followers_url': 'https://api.github.com/users/IsaquePinkuss/followers',
#      'following_url': 'https://api.github.com/users/IsaquePinkuss/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/IsaquePinkuss/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/IsaquePinkuss/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/IsaquePinkuss/subscriptions',
#      'organizations_url': 'https://api.github.com/users/IsaquePinkuss/orgs',
#      'repos_url': 'https://api.github.com/users/IsaquePinkuss/repos',
#      'events_url': 'https://api.github.com/users/IsaquePinkuss/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/IsaquePinkuss/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/IsaquePinkuss/curso-reactjs-ninja',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja',
#     'forks_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/forks',
#     'keys_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/teams',
#     'hooks_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/hooks',
#     'issue_events_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/events',
#     'assignees_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/tags',
#     'blobs_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/languages',
#     'stargazers_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/stargazers',
#     'contributors_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/contributors',
#     'subscribers_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/subscribers',
#     'subscription_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/subscription',
#     'commits_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/merges',
#     'archive_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/downloads',
#     'issues_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/IsaquePinkuss/curso-reactjs-ninja/deployments',
#     'created_at': '2022-02-15T22:42:54Z',
#     'updated_at': '2022-02-15T14:42:57Z',
#     'pushed_at': '2021-07-25T11:41:38Z',
#     'git_url': 'git://github.com/IsaquePinkuss/curso-reactjs-ninja.git',
#     'ssh_url': 'git@github.com:IsaquePinkuss/curso-reactjs-ninja.git',
#     'clone_url': 'https://github.com/IsaquePinkuss/curso-reactjs-ninja.git',
#     'svn_url': 'https://github.com/IsaquePinkuss/curso-reactjs-ninja',
#     'homepage': None,
#     'size': 9428,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z',
#   'org': {'id': 11011075,
#    'login': 'da2k',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/da2k',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11011075?'}},
#  {'id': '20277534509',
#   'type': 'PushEvent',
#   'actor': {'id': 74218504,
#    'login': 'CarterLynch',
#    'display_login': 'CarterLynch',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CarterLynch',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74218504?'},
#   'repo': {'id': 457999874,
#    'name': 'CarterLynch/CityView',
#    'url': 'https://api.github.com/repos/CarterLynch/CityView'},
#   'payload': {'push_id': 9112476180,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8527ad0d54a7a84131b8f1d58ca703babda25e90',
#    'before': '266cb5144a9f98b563880593e753ef58735fafc1',
#    'commits': [{'sha': '8527ad0d54a7a84131b8f1d58ca703babda25e90',
#      'author': {'email': '74218504+CarterLynch@users.noreply.github.com',
#       'name': 'John Lynch'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/CarterLynch/CityView/commits/8527ad0d54a7a84131b8f1d58ca703babda25e90'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534512',
#   'type': 'PushEvent',
#   'actor': {'id': 79855424,
#    'login': 'kucekmill',
#    'display_login': 'kucekmill',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kucekmill',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79855424?'},
#   'repo': {'id': 459768574,
#    'name': 'kucekmill/TG_PH_Downloader_bot',
#    'url': 'https://api.github.com/repos/kucekmill/TG_PH_Downloader_bot'},
#   'payload': {'push_id': 9112476177,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9d5c3fc45e721a81b5afaf70530dcee784e6a9b2',
#    'before': '95e521efb6c123f9cdd9da89cd03e60d3ed52daa',
#    'commits': [{'sha': '9d5c3fc45e721a81b5afaf70530dcee784e6a9b2',
#      'author': {'email': '79855424+kucekmill@users.noreply.github.com',
#       'name': 'Kucekmill'},
#      'message': 'Update requirements.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kucekmill/TG_PH_Downloader_bot/commits/9d5c3fc45e721a81b5afaf70530dcee784e6a9b2'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534502',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 838282,
#    'login': 'simpixelated',
#    'display_login': 'simpixelated',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simpixelated',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/838282?'},
#   'repo': {'id': 137506223,
#    'name': 'simpixelated/simpixelated.com',
#    'url': 'https://api.github.com/repos/simpixelated/simpixelated.com'},
#   'payload': {'action': 'closed',
#    'number': 72,
#    'pull_request': {'url': 'https://api.github.com/repos/simpixelated/simpixelated.com/pulls/72',
#     'id': 853762795,
#     'node_id': 'PR_kwDOCDItr84y42Lr',
#     'html_url': 'https://github.com/simpixelated/simpixelated.com/pull/72',
#     'diff_url': 'https://github.com/simpixelated/simpixelated.com/pull/72.diff',
#     'patch_url': 'https://github.com/simpixelated/simpixelated.com/pull/72.patch',
#     'issue_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/issues/72',
#     'number': 72,
#     'state': 'closed',
#     'locked': False,
#     'title': 'removes duplicate image and updates some blog text',
#     'user': {'login': 'simpixelated',
#      'id': 838282,
#      'node_id': 'MDQ6VXNlcjgzODI4Mg==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/838282?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/simpixelated',
#      'html_url': 'https://github.com/simpixelated',
#      'followers_url': 'https://api.github.com/users/simpixelated/followers',
#      'following_url': 'https://api.github.com/users/simpixelated/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/simpixelated/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/simpixelated/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/simpixelated/subscriptions',
#      'organizations_url': 'https://api.github.com/users/simpixelated/orgs',
#      'repos_url': 'https://api.github.com/users/simpixelated/repos',
#      'events_url': 'https://api.github.com/users/simpixelated/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/simpixelated/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2022-02-15T22:38:13Z',
#     'updated_at': '2022-02-15T22:42:55Z',
#     'closed_at': '2022-02-15T22:42:54Z',
#     'merged_at': '2022-02-15T22:42:54Z',
#     'merge_commit_sha': '4f8b16f38e4f0c2db3b46fe5ed5df53c5d132b21',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/pulls/72/commits',
#     'review_comments_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/pulls/72/comments',
#     'review_comment_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/issues/72/comments',
#     'statuses_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/statuses/e405ff1f394028662dce2f7678fbd61e69f6d2b2',
#     'head': {'label': 'simpixelated:35-interviews-revision',
#      'ref': '35-interviews-revision',
#      'sha': 'e405ff1f394028662dce2f7678fbd61e69f6d2b2',
#      'user': {'login': 'simpixelated',
#       'id': 838282,
#       'node_id': 'MDQ6VXNlcjgzODI4Mg==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/838282?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/simpixelated',
#       'html_url': 'https://github.com/simpixelated',
#       'followers_url': 'https://api.github.com/users/simpixelated/followers',
#       'following_url': 'https://api.github.com/users/simpixelated/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/simpixelated/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/simpixelated/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/simpixelated/subscriptions',
#       'organizations_url': 'https://api.github.com/users/simpixelated/orgs',
#       'repos_url': 'https://api.github.com/users/simpixelated/repos',
#       'events_url': 'https://api.github.com/users/simpixelated/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/simpixelated/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 137506223,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzc1MDYyMjM=',
#       'name': 'simpixelated.com',
#       'full_name': 'simpixelated/simpixelated.com',
#       'private': False,
#       'owner': {'login': 'simpixelated',
#        'id': 838282,
#        'node_id': 'MDQ6VXNlcjgzODI4Mg==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/838282?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/simpixelated',
#        'html_url': 'https://github.com/simpixelated',
#        'followers_url': 'https://api.github.com/users/simpixelated/followers',
#        'following_url': 'https://api.github.com/users/simpixelated/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/simpixelated/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/simpixelated/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/simpixelated/subscriptions',
#        'organizations_url': 'https://api.github.com/users/simpixelated/orgs',
#        'repos_url': 'https://api.github.com/users/simpixelated/repos',
#        'events_url': 'https://api.github.com/users/simpixelated/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/simpixelated/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/simpixelated/simpixelated.com',
#       'description': 'New static generated version of my personal blog.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/simpixelated/simpixelated.com',
#       'forks_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/forks',
#       'keys_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/teams',
#       'hooks_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/hooks',
#       'issue_events_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/events',
#       'assignees_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/tags',
#       'blobs_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/languages',
#       'stargazers_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/stargazers',
#       'contributors_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/contributors',
#       'subscribers_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/subscribers',
#       'subscription_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/subscription',
#       'commits_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/merges',
#       'archive_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/downloads',
#       'issues_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/deployments',
#       'created_at': '2018-06-15T15:51:40Z',
#       'updated_at': '2021-12-02T16:25:41Z',
#       'pushed_at': '2022-02-15T22:42:54Z',
#       'git_url': 'git://github.com/simpixelated/simpixelated.com.git',
#       'ssh_url': 'git@github.com:simpixelated/simpixelated.com.git',
#       'clone_url': 'https://github.com/simpixelated/simpixelated.com.git',
#       'svn_url': 'https://github.com/simpixelated/simpixelated.com',
#       'homepage': 'https://simpixelated.com',
#       'size': 40278,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 2,
#       'default_branch': 'stable'}},
#     'base': {'label': 'simpixelated:stable',
#      'ref': 'stable',
#      'sha': '389adc07c7b1fbd084e1cac3ecb061e7fd2d51f1',
#      'user': {'login': 'simpixelated',
#       'id': 838282,
#       'node_id': 'MDQ6VXNlcjgzODI4Mg==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/838282?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/simpixelated',
#       'html_url': 'https://github.com/simpixelated',
#       'followers_url': 'https://api.github.com/users/simpixelated/followers',
#       'following_url': 'https://api.github.com/users/simpixelated/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/simpixelated/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/simpixelated/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/simpixelated/subscriptions',
#       'organizations_url': 'https://api.github.com/users/simpixelated/orgs',
#       'repos_url': 'https://api.github.com/users/simpixelated/repos',
#       'events_url': 'https://api.github.com/users/simpixelated/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/simpixelated/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 137506223,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzc1MDYyMjM=',
#       'name': 'simpixelated.com',
#       'full_name': 'simpixelated/simpixelated.com',
#       'private': False,
#       'owner': {'login': 'simpixelated',
#        'id': 838282,
#        'node_id': 'MDQ6VXNlcjgzODI4Mg==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/838282?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/simpixelated',
#        'html_url': 'https://github.com/simpixelated',
#        'followers_url': 'https://api.github.com/users/simpixelated/followers',
#        'following_url': 'https://api.github.com/users/simpixelated/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/simpixelated/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/simpixelated/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/simpixelated/subscriptions',
#        'organizations_url': 'https://api.github.com/users/simpixelated/orgs',
#        'repos_url': 'https://api.github.com/users/simpixelated/repos',
#        'events_url': 'https://api.github.com/users/simpixelated/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/simpixelated/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/simpixelated/simpixelated.com',
#       'description': 'New static generated version of my personal blog.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/simpixelated/simpixelated.com',
#       'forks_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/forks',
#       'keys_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/teams',
#       'hooks_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/hooks',
#       'issue_events_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/events',
#       'assignees_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/tags',
#       'blobs_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/languages',
#       'stargazers_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/stargazers',
#       'contributors_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/contributors',
#       'subscribers_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/subscribers',
#       'subscription_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/subscription',
#       'commits_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/merges',
#       'archive_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/downloads',
#       'issues_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/simpixelated/simpixelated.com/deployments',
#       'created_at': '2018-06-15T15:51:40Z',
#       'updated_at': '2021-12-02T16:25:41Z',
#       'pushed_at': '2022-02-15T22:42:54Z',
#       'git_url': 'git://github.com/simpixelated/simpixelated.com.git',
#       'ssh_url': 'git@github.com:simpixelated/simpixelated.com.git',
#       'clone_url': 'https://github.com/simpixelated/simpixelated.com.git',
#       'svn_url': 'https://github.com/simpixelated/simpixelated.com',
#       'homepage': 'https://simpixelated.com',
#       'size': 40278,
#       'stargazers_count': 2,
#       'watchers_count': 2,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 2,
#       'default_branch': 'stable'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/simpixelated/simpixelated.com/pulls/72'},
#      'html': {'href': 'https://github.com/simpixelated/simpixelated.com/pull/72'},
#      'issue': {'href': 'https://api.github.com/repos/simpixelated/simpixelated.com/issues/72'},
#      'comments': {'href': 'https://api.github.com/repos/simpixelated/simpixelated.com/issues/72/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/simpixelated/simpixelated.com/pulls/72/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/simpixelated/simpixelated.com/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/simpixelated/simpixelated.com/pulls/72/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/simpixelated/simpixelated.com/statuses/e405ff1f394028662dce2f7678fbd61e69f6d2b2'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'simpixelated',
#      'id': 838282,
#      'node_id': 'MDQ6VXNlcjgzODI4Mg==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/838282?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/simpixelated',
#      'html_url': 'https://github.com/simpixelated',
#      'followers_url': 'https://api.github.com/users/simpixelated/followers',
#      'following_url': 'https://api.github.com/users/simpixelated/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/simpixelated/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/simpixelated/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/simpixelated/subscriptions',
#      'organizations_url': 'https://api.github.com/users/simpixelated/orgs',
#      'repos_url': 'https://api.github.com/users/simpixelated/repos',
#      'events_url': 'https://api.github.com/users/simpixelated/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/simpixelated/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 4,
#     'deletions': 2,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534510',
#   'type': 'PushEvent',
#   'actor': {'id': 33005571,
#    'login': 'darkcat013',
#    'display_login': 'darkcat013',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/darkcat013',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33005571?'},
#   'repo': {'id': 455352834,
#    'name': 'darkcat013/lfpc-labs',
#    'url': 'https://api.github.com/repos/darkcat013/lfpc-labs'},
#   'payload': {'push_id': 9112476186,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd82bb058cfe1c3934979e2368a8c0a3fbe5f149c',
#    'before': 'dfb8651af9fcd698e71348d061763ce7eb53d4c4',
#    'commits': [{'sha': 'd82bb058cfe1c3934979e2368a8c0a3fbe5f149c',
#      'author': {'email': 'viorel.noroc013@gmail.com', 'name': 'darkcat013'},
#      'message': 'moved folders and renamed csproj',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/darkcat013/lfpc-labs/commits/d82bb058cfe1c3934979e2368a8c0a3fbe5f149c'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534513',
#   'type': 'PushEvent',
#   'actor': {'id': 81263659,
#    'login': 'Brent-Bostwick',
#    'display_login': 'Brent-Bostwick',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Brent-Bostwick',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81263659?'},
#   'repo': {'id': 454598363,
#    'name': 'Brent-Bostwick/SiQuis',
#    'url': 'https://api.github.com/repos/Brent-Bostwick/SiQuis'},
#   'payload': {'push_id': 9112476187,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '699af8bbbe7fe1b964519ed65da8409635fc14d1',
#    'before': '04c1cf37971321eba4b0b20ba65dca26c3e517b8',
#    'commits': [{'sha': '699af8bbbe7fe1b964519ed65da8409635fc14d1',
#      'author': {'email': '81263659+Brent-Bostwick@users.noreply.github.com',
#       'name': 'Brent-Bostwick'},
#      'message': 'Renamed File',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Brent-Bostwick/SiQuis/commits/699af8bbbe7fe1b964519ed65da8409635fc14d1'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534503',
#   'type': 'MemberEvent',
#   'actor': {'id': 33315682,
#    'login': 'pullynnhah',
#    'display_login': 'pullynnhah',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pullynnhah',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33315682?'},
#   'repo': {'id': 459745762,
#    'name': 'pullynnhah/06-projeto-buzz-quizz',
#    'url': 'https://api.github.com/repos/pullynnhah/06-projeto-buzz-quizz'},
#   'payload': {'member': {'login': 'cassandra-mn',
#     'id': 98117185,
#     'node_id': 'U_kgDOBdkmQQ',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/98117185?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/cassandra-mn',
#     'html_url': 'https://github.com/cassandra-mn',
#     'followers_url': 'https://api.github.com/users/cassandra-mn/followers',
#     'following_url': 'https://api.github.com/users/cassandra-mn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/cassandra-mn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/cassandra-mn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/cassandra-mn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/cassandra-mn/orgs',
#     'repos_url': 'https://api.github.com/users/cassandra-mn/repos',
#     'events_url': 'https://api.github.com/users/cassandra-mn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/cassandra-mn/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'action': 'added'},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534504',
#   'type': 'WatchEvent',
#   'actor': {'id': 69774834,
#    'login': 'rishiwahi',
#    'display_login': 'rishiwahi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rishiwahi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69774834?'},
#   'repo': {'id': 17170709,
#    'name': 'iqbal-lab/Mykrobe-predictor',
#    'url': 'https://api.github.com/repos/iqbal-lab/Mykrobe-predictor'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534492',
#   'type': 'PushEvent',
#   'actor': {'id': 1206691,
#    'login': 'wjblanke',
#    'display_login': 'wjblanke',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wjblanke',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1206691?'},
#   'repo': {'id': 197153676,
#    'name': 'Chia-Network/chia-blockchain',
#    'url': 'https://api.github.com/repos/Chia-Network/chia-blockchain'},
#   'payload': {'push_id': 9112476073,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0464265734561121cab27899fa95f7ccdfa1349e',
#    'before': 'f5ade1564c8459bcf12f6dd92706248c8061f3fb',
#    'commits': [{'sha': '0464265734561121cab27899fa95f7ccdfa1349e',
#      'author': {'email': 'arvid@libtorrent.org', 'name': 'Arvid Norberg'},
#      'message': 'use monotonic clock in benchmarks (#10242)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Chia-Network/chia-blockchain/commits/0464265734561121cab27899fa95f7ccdfa1349e'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z',
#   'org': {'id': 34047804,
#    'login': 'Chia-Network',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Chia-Network',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34047804?'}},
#  {'id': '20277534508',
#   'type': 'CreateEvent',
#   'actor': {'id': 13922635,
#    'login': 'jpmmota',
#    'display_login': 'jpmmota',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jpmmota',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13922635?'},
#   'repo': {'id': 459774021,
#    'name': 'jpmmota/terraform-study',
#    'url': 'https://api.github.com/repos/jpmmota/terraform-study'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'Terraform study',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534496',
#   'type': 'WatchEvent',
#   'actor': {'id': 5790897,
#    'login': 'jdubhghaill',
#    'display_login': 'jdubhghaill',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jdubhghaill',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5790897?'},
#   'repo': {'id': 30064588,
#    'name': 'video-dev/hls.js',
#    'url': 'https://api.github.com/repos/video-dev/hls.js'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z',
#   'org': {'id': 25984302,
#    'login': 'video-dev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/video-dev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25984302?'}},
#  {'id': '20277534525',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 20955511,
#    'login': 'DenverCoder1',
#    'display_login': 'DenverCoder1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DenverCoder1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20955511?'},
#   'repo': {'id': 400793998,
#    'name': 'nextcord/nextcord',
#    'url': 'https://api.github.com/repos/nextcord/nextcord'},
#   'payload': {'action': 'created',
#    'review': {'id': 883736520,
#     'node_id': 'PRR_kwDOF-Ohjs40rL_I',
#     'user': {'login': 'DenverCoder1',
#      'id': 20955511,
#      'node_id': 'MDQ6VXNlcjIwOTU1NTEx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/20955511?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/DenverCoder1',
#      'html_url': 'https://github.com/DenverCoder1',
#      'followers_url': 'https://api.github.com/users/DenverCoder1/followers',
#      'following_url': 'https://api.github.com/users/DenverCoder1/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DenverCoder1/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/DenverCoder1/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DenverCoder1/subscriptions',
#      'organizations_url': 'https://api.github.com/users/DenverCoder1/orgs',
#      'repos_url': 'https://api.github.com/users/DenverCoder1/repos',
#      'events_url': 'https://api.github.com/users/DenverCoder1/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/DenverCoder1/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'commit_id': '69e5030b410428d341cbe7823b613cfcc846a180',
#     'submitted_at': '2022-02-15T22:42:55Z',
#     'state': 'approved',
#     'html_url': 'https://github.com/nextcord/nextcord/pull/469#pullrequestreview-883736520',
#     'pull_request_url': 'https://api.github.com/repos/nextcord/nextcord/pulls/469',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'html': {'href': 'https://github.com/nextcord/nextcord/pull/469#pullrequestreview-883736520'},
#      'pull_request': {'href': 'https://api.github.com/repos/nextcord/nextcord/pulls/469'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/nextcord/nextcord/pulls/469',
#     'id': 853746779,
#     'node_id': 'PR_kwDOF-Ohjs4y4yRb',
#     'html_url': 'https://github.com/nextcord/nextcord/pull/469',
#     'diff_url': 'https://github.com/nextcord/nextcord/pull/469.diff',
#     'patch_url': 'https://github.com/nextcord/nextcord/pull/469.patch',
#     'issue_url': 'https://api.github.com/repos/nextcord/nextcord/issues/469',
#     'number': 469,
#     'state': 'open',
#     'locked': False,
#     'title': 'Task bugfix and refactoring',
#     'user': {'login': 'veni-vidi-code',
#      'id': 71394987,
#      'node_id': 'MDQ6VXNlcjcxMzk0OTg3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/71394987?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/veni-vidi-code',
# ...
#       'homepage': None,
#       'size': 2,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'mfranciscao:main',
#      'ref': 'main',
#      'sha': '8059c550625f6e834cdf5b03d578336556d8d4e1',
#      'user': {'login': 'mfranciscao',
#       'id': 77557281,
#       'node_id': 'MDQ6VXNlcjc3NTU3Mjgx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/77557281?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mfranciscao',
#       'html_url': 'https://github.com/mfranciscao',
#       'followers_url': 'https://api.github.com/users/mfranciscao/followers',
#       'following_url': 'https://api.github.com/users/mfranciscao/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mfranciscao/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mfranciscao/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mfranciscao/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mfranciscao/orgs',
#       'repos_url': 'https://api.github.com/users/mfranciscao/repos',
#       'events_url': 'https://api.github.com/users/mfranciscao/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mfranciscao/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 459746516,
#       'node_id': 'R_kgDOG2cs1A',
#       'name': 'ciencia_de_dados',
#       'full_name': 'mfranciscao/ciencia_de_dados',
#       'private': False,
#       'owner': {'login': 'mfranciscao',
#        'id': 77557281,
#        'node_id': 'MDQ6VXNlcjc3NTU3Mjgx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/77557281?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mfranciscao',
#        'html_url': 'https://github.com/mfranciscao',
#        'followers_url': 'https://api.github.com/users/mfranciscao/followers',
#        'following_url': 'https://api.github.com/users/mfranciscao/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mfranciscao/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mfranciscao/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mfranciscao/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mfranciscao/orgs',
#        'repos_url': 'https://api.github.com/users/mfranciscao/repos',
#        'events_url': 'https://api.github.com/users/mfranciscao/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mfranciscao/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/mfranciscao/ciencia_de_dados',
#       'description': 'Tarefa de ciência de dados - aula 1',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados',
#       'forks_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/forks',
#       'keys_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/teams',
#       'hooks_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/events',
#       'assignees_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/tags',
#       'blobs_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/languages',
#       'stargazers_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/subscription',
#       'commits_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/merges',
#       'archive_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/downloads',
#       'issues_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/deployments',
#       'created_at': '2022-02-15T20:54:41Z',
#       'updated_at': '2022-02-15T22:42:09Z',
#       'pushed_at': '2022-02-15T22:42:54Z',
#       'git_url': 'git://github.com/mfranciscao/ciencia_de_dados.git',
#       'ssh_url': 'git@github.com:mfranciscao/ciencia_de_dados.git',
#       'clone_url': 'https://github.com/mfranciscao/ciencia_de_dados.git',
#       'svn_url': 'https://github.com/mfranciscao/ciencia_de_dados',
#       'homepage': None,
#       'size': 2,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/pulls/8'},
#      'html': {'href': 'https://github.com/mfranciscao/ciencia_de_dados/pull/8'},
#      'issue': {'href': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/issues/8'},
#      'comments': {'href': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/issues/8/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/pulls/8/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/pulls/8/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/mfranciscao/ciencia_de_dados/statuses/483058dd094e555fd350295486aeb17b3f1fe4e4'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'marcospfduarte',
#      'id': 56883295,
#      'node_id': 'MDQ6VXNlcjU2ODgzMjk1',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/56883295?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/marcospfduarte',
#      'html_url': 'https://github.com/marcospfduarte',
#      'followers_url': 'https://api.github.com/users/marcospfduarte/followers',
#      'following_url': 'https://api.github.com/users/marcospfduarte/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/marcospfduarte/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/marcospfduarte/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/marcospfduarte/subscriptions',
#      'organizations_url': 'https://api.github.com/users/marcospfduarte/orgs',
#      'repos_url': 'https://api.github.com/users/marcospfduarte/repos',
#      'events_url': 'https://api.github.com/users/marcospfduarte/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/marcospfduarte/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534488',
#   'type': 'PushEvent',
#   'actor': {'id': 53666880,
#    'login': 'chadtarpey615',
#    'display_login': 'chadtarpey615',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chadtarpey615',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53666880?'},
#   'repo': {'id': 449482578,
#    'name': 'chadtarpey615/coordinator001',
#    'url': 'https://api.github.com/repos/chadtarpey615/coordinator001'},
#   'payload': {'push_id': 9112476147,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2e51596f0ea6eaf4a7752542a7c30db568206cbb',
#    'before': '747c8f209f30984b654954658894a078717c2010',
#    'commits': [{'sha': '2e51596f0ea6eaf4a7752542a7c30db568206cbb',
#      'author': {'email': 'chadtarpey@gmail.com', 'name': 'Chad Tarpey'},
#      'message': 'setup frontend and backend folders to split up application',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/chadtarpey615/coordinator001/commits/2e51596f0ea6eaf4a7752542a7c30db568206cbb'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534487',
#   'type': 'PushEvent',
#   'actor': {'id': 76050967,
#    'login': 'muttito',
#    'display_login': 'muttito',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/muttito',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76050967?'},
#   'repo': {'id': 317584435,
#    'name': 'MuttData/muttlib',
#    'url': 'https://api.github.com/repos/MuttData/muttlib'},
#   'payload': {'push_id': 9112476157,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cbd8f3e9673ca345fbcfcbef66778950b8d0f724',
#    'before': '29aa349bc88b0dab00333d110ea7e137b9d315ca',
#    'commits': [{'sha': 'cbd8f3e9673ca345fbcfcbef66778950b8d0f724',
#      'author': {'email': 'ijmermet@gmail.com', 'name': 'CrossNox'},
#      'message': 'Fix sphinx-build, as in upcoming MR',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MuttData/muttlib/commits/cbd8f3e9673ca345fbcfcbef66778950b8d0f724'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z',
#   'org': {'id': 36137896,
#    'login': 'MuttData',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/MuttData',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36137896?'}},
#  {'id': '20277534479',
#   'type': 'PushEvent',
#   'actor': {'id': 59847353,
#    'login': 'infaautovcs',
#    'display_login': 'infaautovcs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/infaautovcs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59847353?'},
#   'repo': {'id': 362203021,
#    'name': 'infaautovcs/DependencyUIAuto',
#    'url': 'https://api.github.com/repos/infaautovcs/DependencyUIAuto'},
#   'payload': {'push_id': 9112476159,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '85bf51ca2b03a7b243a23fb95293a12a8236767d',
#    'before': '9bd3b81d7002b97b0af199b201b1635216ccabbe',
#    'commits': [{'sha': '85bf51ca2b03a7b243a23fb95293a12a8236767d',
#      'author': {'email': 'nmani@informatica.com',
#       'name': 'azure_germany_prod'},
#      'message': 'Automation summary\n\nAutomation Desc',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/infaautovcs/DependencyUIAuto/commits/85bf51ca2b03a7b243a23fb95293a12a8236767d'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534472',
#   'type': 'CreateEvent',
#   'actor': {'id': 32886269,
#    'login': 'nmorrish',
#    'display_login': 'nmorrish',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nmorrish',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32886269?'},
#   'repo': {'id': 459773674,
#    'name': 'nmorrish/NumberListScrambler',
#    'url': 'https://api.github.com/repos/nmorrish/NumberListScrambler'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534465',
#   'type': 'PushEvent',
#   'actor': {'id': 78501533,
#    'login': 'graphicsdoth',
#    'display_login': 'graphicsdoth',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/graphicsdoth',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78501533?'},
#   'repo': {'id': 459301040,
#    'name': 'graphicsdoth/Healthcare-Analytics',
#    'url': 'https://api.github.com/repos/graphicsdoth/Healthcare-Analytics'},
#   'payload': {'push_id': 9112476151,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '96bb9f9ebd68be4296c63add4be137fc7b6ca33e',
#    'before': '4f6bede48082c70336f10078f9483750f681cfd3',
#    'commits': [{'sha': '96bb9f9ebd68be4296c63add4be137fc7b6ca33e',
#      'author': {'email': '78501533+graphicsdoth@users.noreply.github.com',
#       'name': 'Anisha Joshi'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/graphicsdoth/Healthcare-Analytics/commits/96bb9f9ebd68be4296c63add4be137fc7b6ca33e'}]},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'},
#  {'id': '20277534444',
#   'type': 'CreateEvent',
#   'actor': {'id': 81279470,
#    'login': 'favroautomations',
#    'display_login': 'favroautomations',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/favroautomations',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81279470?'},
#   'repo': {'id': 459774020,
#    'name': 'favroautomations/automationgitlabrunner17',
#    'url': 'https://api.github.com/repos/favroautomations/automationgitlabrunner17'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-02-15T22:42:55Z'}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                    type  \
# 0   20277534561               PushEvent
# 1   20277534579               PushEvent
# 2   20277534571               PushEvent
# 3   20277534555             CreateEvent
# 4   20277534572             CreateEvent
# 5   20277534529               PushEvent
# 6   20277534537               PushEvent
# 7   20277534550               PushEvent
# 8   20277534522               ForkEvent
# 9   20277534509               PushEvent
# 10  20277534512               PushEvent
# 11  20277534502        PullRequestEvent
# 12  20277534510               PushEvent
# 13  20277534513               PushEvent
# 14  20277534503             MemberEvent
# 15  20277534504              WatchEvent
# 16  20277534492               PushEvent
# 17  20277534508             CreateEvent
# 18  20277534496              WatchEvent
# 19  20277534525  PullRequestReviewEvent
# 20  20277534517               ForkEvent
# 21  20277534495               PushEvent
# 22  20277534475               PushEvent
# 23  20277534494        PullRequestEvent
# 24  20277534488               PushEvent
# 25  20277534487               PushEvent
# 26  20277534479               PushEvent
# 27  20277534472             CreateEvent
# 28  20277534465               PushEvent
# 29  20277534444             CreateEvent
#
#                                                 actor  \
# 0   {'id': 13855126, 'login': 'marek-hanzal', 'dis...
# 1   {'id': 89932011, 'login': 'raiderpls', 'displa...
# 2   {'id': 2334215, 'login': 'suluke', 'display_lo...
# 3   {'id': 62577524, 'login': 'tan14142', 'display...
# 4   {'id': 33194722, 'login': '1elirantoledano', '...
# 5   {'id': 77168453, 'login': 'kimjensen-hpe', 'di...
# 6   {'id': 56883295, 'login': 'marcospfduarte', 'd...
# 7   {'id': 13355009, 'login': 'AgentOxygen', 'disp...
# 8   {'id': 75698082, 'login': 'IsaquePinkuss', 'di...
# 9   {'id': 74218504, 'login': 'CarterLynch', 'disp...
# 10  {'id': 79855424, 'login': 'kucekmill', 'displa...
# 11  {'id': 838282, 'login': 'simpixelated', 'displ...
# 12  {'id': 33005571, 'login': 'darkcat013', 'displ...
# 13  {'id': 81263659, 'login': 'Brent-Bostwick', 'd...
# 14  {'id': 33315682, 'login': 'pullynnhah', 'displ...
# 15  {'id': 69774834, 'login': 'rishiwahi', 'displa...
# 16  {'id': 1206691, 'login': 'wjblanke', 'display_...
# 17  {'id': 13922635, 'login': 'jpmmota', 'display_...
# 18  {'id': 5790897, 'login': 'jdubhghaill', 'displ...
# 19  {'id': 20955511, 'login': 'DenverCoder1', 'dis...
# 20  {'id': 26311663, 'login': 'Runig006', 'display...
# 21  {'id': 11540112, 'login': 'michal-z', 'display...
# 22  {'id': 40635383, 'login': 'KalinLai-void', 'di...
# 23  {'id': 56883295, 'login': 'marcospfduarte', 'd...
# 24  {'id': 53666880, 'login': 'chadtarpey615', 'di...
# 25  {'id': 76050967, 'login': 'muttito', 'display_...
# 26  {'id': 59847353, 'login': 'infaautovcs', 'disp...
# 27  {'id': 32886269, 'login': 'nmorrish', 'display...
# 28  {'id': 78501533, 'login': 'graphicsdoth', 'dis...
# 29  {'id': 81279470, 'login': 'favroautomations', ...
#
#                                                  repo  \
# 0   {'id': 394701910, 'name': 'marek-hanzal/puff-s...
# 1   {'id': 458976759, 'name': 'raiderpls/tiny-form...
# 2   {'id': 423557122, 'name': 'suluke/ultrustar', ...
# 3   {'id': 459774024, 'name': 'tan14142/wordle', '...
# 4   {'id': 459748702, 'name': '1elirantoledano/Sho...
# 5   {'id': 386357982, 'name': 'Cray-HPE/csm-testin...
# 6   {'id': 459746516, 'name': 'mfranciscao/ciencia...
# 7   {'id': 445943421, 'name': 'AgentOxygen/java_ga...
# 8   {'id': 59958668, 'name': 'da2k/curso-reactjs-n...
# 9   {'id': 457999874, 'name': 'CarterLynch/CityVie...
# 10  {'id': 459768574, 'name': 'kucekmill/TG_PH_Dow...
# 11  {'id': 137506223, 'name': 'simpixelated/simpix...
# 12  {'id': 455352834, 'name': 'darkcat013/lfpc-lab...
# 13  {'id': 454598363, 'name': 'Brent-Bostwick/SiQu...
# 14  {'id': 459745762, 'name': 'pullynnhah/06-proje...
# 15  {'id': 17170709, 'name': 'iqbal-lab/Mykrobe-pr...
# 16  {'id': 197153676, 'name': 'Chia-Network/chia-b...
# 17  {'id': 459774021, 'name': 'jpmmota/terraform-s...
# 18  {'id': 30064588, 'name': 'video-dev/hls.js', '...
# 19  {'id': 400793998, 'name': 'nextcord/nextcord',...
# 20  {'id': 376259658, 'name': 'MelihAltintas/vue3-...
# 21  {'id': 386660816, 'name': 'michal-z/zig-gamede...
# 22  {'id': 459309299, 'name': 'KalinLai-void/ACGN'...
# 23  {'id': 459746516, 'name': 'mfranciscao/ciencia...
# 24  {'id': 449482578, 'name': 'chadtarpey615/coord...
# 25  {'id': 317584435, 'name': 'MuttData/muttlib', ...
# 26  {'id': 362203021, 'name': 'infaautovcs/Depende...
# 27  {'id': 459773674, 'name': 'nmorrish/NumberList...
# 28  {'id': 459301040, 'name': 'graphicsdoth/Health...
# 29  {'id': 459774020, 'name': 'favroautomations/au...
#
#                                               payload  public  \
# 0   {'push_id': 9112476198, 'size': 1, 'distinct_s...    True
# 1   {'push_id': 9112476203, 'size': 1, 'distinct_s...    True
# 2   {'push_id': 9112476213, 'size': 1, 'distinct_s...    True
# 3   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 4   {'ref': 'dev', 'ref_type': 'branch', 'master_b...    True
# 5   {'push_id': 9112476189, 'size': 1, 'distinct_s...    True
# 6   {'push_id': 9112476201, 'size': 2, 'distinct_s...    True
# 7   {'push_id': 9112476192, 'size': 1, 'distinct_s...    True
# 8   {'forkee': {'id': 459774023, 'node_id': 'R_kgD...    True
# 9   {'push_id': 9112476180, 'size': 1, 'distinct_s...    True
# 10  {'push_id': 9112476177, 'size': 1, 'distinct_s...    True
# 11  {'action': 'closed', 'number': 72, 'pull_reque...    True
# 12  {'push_id': 9112476186, 'size': 1, 'distinct_s...    True
# 13  {'push_id': 9112476187, 'size': 1, 'distinct_s...    True
# 14  {'member': {'login': 'cassandra-mn', 'id': 981...    True
# 15                              {'action': 'started'}    True
# 16  {'push_id': 9112476073, 'size': 1, 'distinct_s...    True
# 17  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 18                              {'action': 'started'}    True
# 19  {'action': 'created', 'review': {'id': 8837365...    True
# 20  {'forkee': {'id': 459774022, 'node_id': 'R_kgD...    True
# 21  {'push_id': 9112476045, 'size': 1, 'distinct_s...    True
# 22  {'push_id': 9112476161, 'size': 1, 'distinct_s...    True
# 23  {'action': 'closed', 'number': 8, 'pull_reques...    True
# 24  {'push_id': 9112476147, 'size': 1, 'distinct_s...    True
# 25  {'push_id': 9112476157, 'size': 1, 'distinct_s...    True
# 26  {'push_id': 9112476159, 'size': 1, 'distinct_s...    True
# 27  {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 28  {'push_id': 9112476151, 'size': 1, 'distinct_s...    True
# 29  {'ref': None, 'ref_type': 'repository', 'maste...    True
#
#               created_at                                                org
# 0   2022-02-15T22:42:55Z                                                NaN
# 1   2022-02-15T22:42:55Z                                                NaN
# 2   2022-02-15T22:42:55Z                                                NaN
# 3   2022-02-15T22:42:55Z                                                NaN
# 4   2022-02-15T22:42:55Z                                                NaN
# 5   2022-02-15T22:42:55Z  {'id': 74066787, 'login': 'Cray-HPE', 'gravata...
# 6   2022-02-15T22:42:55Z                                                NaN
# 7   2022-02-15T22:42:55Z                                                NaN
# 8   2022-02-15T22:42:55Z  {'id': 11011075, 'login': 'da2k', 'gravatar_id...
# 9   2022-02-15T22:42:55Z                                                NaN
# 10  2022-02-15T22:42:55Z                                                NaN
# 11  2022-02-15T22:42:55Z                                                NaN
# 12  2022-02-15T22:42:55Z                                                NaN
# 13  2022-02-15T22:42:55Z                                                NaN
# 14  2022-02-15T22:42:55Z                                                NaN
# 15  2022-02-15T22:42:55Z                                                NaN
# 16  2022-02-15T22:42:55Z  {'id': 34047804, 'login': 'Chia-Network', 'gra...
# 17  2022-02-15T22:42:55Z                                                NaN
# 18  2022-02-15T22:42:55Z  {'id': 25984302, 'login': 'video-dev', 'gravat...
# 19  2022-02-15T22:42:55Z  {'id': 89693200, 'login': 'nextcord', 'gravata...
# 20  2022-02-15T22:42:55Z                                                NaN
# 21  2022-02-15T22:42:55Z                                                NaN
# 22  2022-02-15T22:42:55Z                                                NaN
# 23  2022-02-15T22:42:55Z                                                NaN
# 24  2022-02-15T22:42:55Z                                                NaN
# 25  2022-02-15T22:42:55Z  {'id': 36137896, 'login': 'MuttData', 'gravata...
# 26  2022-02-15T22:42:55Z                                                NaN
# 27  2022-02-15T22:42:55Z                                                NaN
# 28  2022-02-15T22:42:55Z                                                NaN
# 29  2022-02-15T22:42:55Z                                                NaN

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id                    type  public            created_at  \
# 0   20277534561               PushEvent    True  2022-02-15T22:42:55Z
# 1   20277534579               PushEvent    True  2022-02-15T22:42:55Z
# 2   20277534571               PushEvent    True  2022-02-15T22:42:55Z
# 3   20277534555             CreateEvent    True  2022-02-15T22:42:55Z
# 4   20277534572             CreateEvent    True  2022-02-15T22:42:55Z
# 5   20277534529               PushEvent    True  2022-02-15T22:42:55Z
# 6   20277534537               PushEvent    True  2022-02-15T22:42:55Z
# 7   20277534550               PushEvent    True  2022-02-15T22:42:55Z
# 8   20277534522               ForkEvent    True  2022-02-15T22:42:55Z
# 9   20277534509               PushEvent    True  2022-02-15T22:42:55Z
# 10  20277534512               PushEvent    True  2022-02-15T22:42:55Z
# 11  20277534502        PullRequestEvent    True  2022-02-15T22:42:55Z
# 12  20277534510               PushEvent    True  2022-02-15T22:42:55Z
# 13  20277534513               PushEvent    True  2022-02-15T22:42:55Z
# 14  20277534503             MemberEvent    True  2022-02-15T22:42:55Z
# 15  20277534504              WatchEvent    True  2022-02-15T22:42:55Z
# 16  20277534492               PushEvent    True  2022-02-15T22:42:55Z
# 17  20277534508             CreateEvent    True  2022-02-15T22:42:55Z
# 18  20277534496              WatchEvent    True  2022-02-15T22:42:55Z
# 19  20277534525  PullRequestReviewEvent    True  2022-02-15T22:42:55Z
# 20  20277534517               ForkEvent    True  2022-02-15T22:42:55Z
# 21  20277534495               PushEvent    True  2022-02-15T22:42:55Z
# 22  20277534475               PushEvent    True  2022-02-15T22:42:55Z
# 23  20277534494        PullRequestEvent    True  2022-02-15T22:42:55Z
# 24  20277534488               PushEvent    True  2022-02-15T22:42:55Z
# 25  20277534487               PushEvent    True  2022-02-15T22:42:55Z
# 26  20277534479               PushEvent    True  2022-02-15T22:42:55Z
# 27  20277534472             CreateEvent    True  2022-02-15T22:42:55Z
# 28  20277534465               PushEvent    True  2022-02-15T22:42:55Z
# 29  20277534444             CreateEvent    True  2022-02-15T22:42:55Z
#
#     actor.id       actor.login actor.display_login actor.gravatar_id  \
# 0   13855126      marek-hanzal        marek-hanzal
# 1   89932011         raiderpls           raiderpls
# 2    2334215            suluke              suluke
# 3   62577524          tan14142            tan14142
# 4   33194722   1elirantoledano     1elirantoledano
# 5   77168453     kimjensen-hpe       kimjensen-hpe
# 6   56883295    marcospfduarte      marcospfduarte
# 7   13355009       AgentOxygen         AgentOxygen
# 8   75698082     IsaquePinkuss       IsaquePinkuss
# 9   74218504       CarterLynch         CarterLynch
# 10  79855424         kucekmill           kucekmill
# 11    838282      simpixelated        simpixelated
# 12  33005571        darkcat013          darkcat013
# 13  81263659    Brent-Bostwick      Brent-Bostwick
# 14  33315682        pullynnhah          pullynnhah
# 15  69774834         rishiwahi           rishiwahi
# 16   1206691          wjblanke            wjblanke
# 17  13922635           jpmmota             jpmmota
# 18   5790897       jdubhghaill         jdubhghaill
# 19  20955511      DenverCoder1        DenverCoder1
# 20  26311663          Runig006            Runig006
# 21  11540112          michal-z            michal-z
# 22  40635383     KalinLai-void       KalinLai-void
# 23  56883295    marcospfduarte      marcospfduarte
# 24  53666880     chadtarpey615       chadtarpey615
# 25  76050967           muttito             muttito
# 26  59847353       infaautovcs         infaautovcs
# 27  32886269          nmorrish            nmorrish
# 28  78501533      graphicsdoth        graphicsdoth
# 29  81279470  favroautomations    favroautomations
#
#                                         actor.url  \
# 0       https://api.github.com/users/marek-hanzal
# 1          https://api.github.com/users/raiderpls
# 2             https://api.github.com/users/suluke
# 3           https://api.github.com/users/tan14142
# 4    https://api.github.com/users/1elirantoledano
# 5      https://api.github.com/users/kimjensen-hpe
# 6     https://api.github.com/users/marcospfduarte
# 7        https://api.github.com/users/AgentOxygen
# 8      https://api.github.com/users/IsaquePinkuss
# 9        https://api.github.com/users/CarterLynch
# 10         https://api.github.com/users/kucekmill
# 11      https://api.github.com/users/simpixelated
# 12        https://api.github.com/users/darkcat013
# 13    https://api.github.com/users/Brent-Bostwick
# 14        https://api.github.com/users/pullynnhah
# 15         https://api.github.com/users/rishiwahi
# 16          https://api.github.com/users/wjblanke
# 17           https://api.github.com/users/jpmmota
# 18       https://api.github.com/users/jdubhghaill
# 19      https://api.github.com/users/DenverCoder1
# 20          https://api.github.com/users/Runig006
# 21          https://api.github.com/users/michal-z
# 22     https://api.github.com/users/KalinLai-void
# 23    https://api.github.com/users/marcospfduarte
# 24     https://api.github.com/users/chadtarpey615
# 25           https://api.github.com/users/muttito
# 26       https://api.github.com/users/infaautovcs
# 27          https://api.github.com/users/nmorrish
# 28      https://api.github.com/users/graphicsdoth
# 29  https://api.github.com/users/favroautomations
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/13855126?  ...
# 1   https://avatars.githubusercontent.com/u/89932011?  ...
# 2    https://avatars.githubusercontent.com/u/2334215?  ...
# 3   https://avatars.githubusercontent.com/u/62577524?  ...
# 4   https://avatars.githubusercontent.com/u/33194722?  ...
# 5   https://avatars.githubusercontent.com/u/77168453?  ...
# 6   https://avatars.githubusercontent.com/u/56883295?  ...
# 7   https://avatars.githubusercontent.com/u/13355009?  ...
# 8   https://avatars.githubusercontent.com/u/75698082?  ...
# 9   https://avatars.githubusercontent.com/u/74218504?  ...
# 10  https://avatars.githubusercontent.com/u/79855424?  ...
# 11    https://avatars.githubusercontent.com/u/838282?  ...
# 12  https://avatars.githubusercontent.com/u/33005571?  ...
# 13  https://avatars.githubusercontent.com/u/81263659?  ...
# 14  https://avatars.githubusercontent.com/u/33315682?  ...
# 15  https://avatars.githubusercontent.com/u/69774834?  ...
# 16   https://avatars.githubusercontent.com/u/1206691?  ...
# 17  https://avatars.githubusercontent.com/u/13922635?  ...
# 18   https://avatars.githubusercontent.com/u/5790897?  ...
# 19  https://avatars.githubusercontent.com/u/20955511?  ...
# 20  https://avatars.githubusercontent.com/u/26311663?  ...
# 21  https://avatars.githubusercontent.com/u/11540112?  ...
# 22  https://avatars.githubusercontent.com/u/40635383?  ...
# 23  https://avatars.githubusercontent.com/u/56883295?  ...
# 24  https://avatars.githubusercontent.com/u/53666880?  ...
# 25  https://avatars.githubusercontent.com/u/76050967?  ...
# 26  https://avatars.githubusercontent.com/u/59847353?  ...
# 27  https://avatars.githubusercontent.com/u/32886269?  ...
# 28  https://avatars.githubusercontent.com/u/78501533?  ...
# 29  https://avatars.githubusercontent.com/u/81279470?  ...
#
#     payload.review.author_association  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                                NaN
# 19                        CONTRIBUTOR
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
#
#                       payload.review._links.html.href  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  https://github.com/nextcord/nextcord/pull/469#...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#               payload.review._links.pull_request.href  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  https://api.github.com/repos/nextcord/nextcord...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#     payload.forkee.license.key  payload.forkee.license.name  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# 5                          NaN                          NaN
# 6                          NaN                          NaN
# 7                          NaN                          NaN
# 8                          NaN                          NaN
# 9                          NaN                          NaN
# 10                         NaN                          NaN
# 11                         NaN                          NaN
# 12                         NaN                          NaN
# 13                         NaN                          NaN
# 14                         NaN                          NaN
# 15                         NaN                          NaN
# 16                         NaN                          NaN
# 17                         NaN                          NaN
# 18                         NaN                          NaN
# 19                         NaN                          NaN
# 20                         mit                  MIT License
# 21                         NaN                          NaN
# 22                         NaN                          NaN
# 23                         NaN                          NaN
# 24                         NaN                          NaN
# 25                         NaN                          NaN
# 26                         NaN                          NaN
# 27                         NaN                          NaN
# 28                         NaN                          NaN
# 29                         NaN                          NaN
#
#     payload.forkee.license.spdx_id           payload.forkee.license.url  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
# 5                              NaN                                  NaN
# 6                              NaN                                  NaN
# 7                              NaN                                  NaN
# 8                              NaN                                  NaN
# 9                              NaN                                  NaN
# 10                             NaN                                  NaN
# 11                             NaN                                  NaN
# 12                             NaN                                  NaN
# 13                             NaN                                  NaN
# 14                             NaN                                  NaN
# 15                             NaN                                  NaN
# 16                             NaN                                  NaN
# 17                             NaN                                  NaN
# 18                             NaN                                  NaN
# 19                             NaN                                  NaN
# 20                             MIT  https://api.github.com/licenses/mit
# 21                             NaN                                  NaN
# 22                             NaN                                  NaN
# 23                             NaN                                  NaN
# 24                             NaN                                  NaN
# 25                             NaN                                  NaN
# 26                             NaN                                  NaN
# 27                             NaN                                  NaN
# 28                             NaN                                  NaN
# 29                             NaN                                  NaN
#
#    payload.forkee.license.node_id payload.pull_request.head.repo.license  \
# 0                             NaN                                    NaN
# 1                             NaN                                    NaN
# 2                             NaN                                    NaN
# 3                             NaN                                    NaN
# 4                             NaN                                    NaN
# 5                             NaN                                    NaN
# 6                             NaN                                    NaN
# 7                             NaN                                    NaN
# 8                             NaN                                    NaN
# 9                             NaN                                    NaN
# 10                            NaN                                    NaN
# 11                            NaN                                    NaN
# 12                            NaN                                    NaN
# 13                            NaN                                    NaN
# 14                            NaN                                    NaN
# 15                            NaN                                    NaN
# 16                            NaN                                    NaN
# 17                            NaN                                    NaN
# 18                            NaN                                    NaN
# 19                            NaN                                    NaN
# 20               MDc6TGljZW5zZTEz                                    NaN
# 21                            NaN                                    NaN
# 22                            NaN                                    NaN
# 23                            NaN                                    NaN
# 24                            NaN                                    NaN
# 25                            NaN                                    NaN
# 26                            NaN                                    NaN
# 27                            NaN                                    NaN
# 28                            NaN                                    NaN
# 29                            NaN                                    NaN
#
#    payload.pull_request.base.repo.license
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
#
# [30 rows x 505 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'iss_position': {'latitude': '-17.3946', 'longitude': '74.1878'},
#  'message': 'success',
#  'timestamp': 1644965400}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"lat": 52.53370520371973, "lon": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312'

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1644965430,
#   'latitude': 52.53370520371973,
#   'longitude': 13.453475292072312,
#   'passes': 5},
#  'response': [{'duration': 350, 'risetime': 1644988708},
#   {'duration': 603, 'risetime': 1644994325},
#   {'duration': 649, 'risetime': 1645000084},
#   {'duration': 651, 'risetime': 1645005884},
#   {'duration': 629, 'risetime': 1645011686}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1637772367)
# Out:
# datetime.datetime(2021, 11, 24, 17, 46, 7)

# %%
pd.to_datetime(1637772367, unit="s")
# Out:
# Timestamp('2021-11-24 16:46:07')

# %% [markdown]
# ### Weather API
#
# Create an account at RapidAPI and "subscribe" to the Weather API: https://rapidapi.com/weatherbit/api/

# %%
import requests

## https://rapidapi.com/community/api/open-weather-map/
url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

#My location coords: lat: 40.545111, lon: -4.204942
querystring = {"lon":"-4.204942","lat":"40.545111"}
querystring["units"] ="metric"
querystring["lang"] = "en"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gh/s8b9pd096y13z1bxsq63d0x40000gn/T/ipykernel_33898/494424325.py in <module>
#      10
#      11 headers = {
# ---> 12     'x-rapidapi-key': x_rapidapi_key,
#      13     'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
#      14     }
#
# NameError: name 'x_rapidapi_key' is not defined

# %%
results = response.json()
print(results)
type(results)
# Out:
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1644965430, 'latitude': 52.53370520371973, 'longitude': 13.453475292072312, 'passes': 5}, 'response': [{'duration': 350, 'risetime': 1644988708}, {'duration': 603, 'risetime': 1644994325}, {'duration': 649, 'risetime': 1645000084}, {'duration': 651, 'risetime': 1645005884}, {'duration': 629, 'risetime': 1645011686}]}
# dict

# %%
results.keys()
# Out:
# dict_keys(['message', 'request', 'response'])

# %% [markdown]
# Getting the forecast for the next 5 days at a 3h intervals

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

headers = {
    'x-rapidapi-key': x_rapidapi_key,
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
results = response.json()
print(results)
# Out:
# {'data': [{'wind_cdir': 'ENE', 'rh': 39, 'pod': 'd', 'timestamp_utc': '2021-06-15T09:00:00', 'pres': 884.145, 'solar_rad': 564.782, 'ozone': 336, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 11.5571, 'timestamp_local': '2021-06-15T11:00:00', 'snow_depth': 0, 'clouds': 69, 'ts': 1623747600, 'wind_spd': 4.07371, 'pop': 15, 'wind_cdir_full': 'east-northeast', 'slp': 1018.79, 'dni': 868.79, 'dewpt': 7.9, 'snow': 0, 'uv': 2.81755, 'wind_dir': 78, 'clouds_hi': 0, 'precip': 0.001953125, 'vis': 24.128, 'dhi': 103.41, 'app_temp': 22.4, 'datetime': '2021-06-15:09', 'temp': 23, 'ghi': 717.09, 'clouds_mid': 69, 'clouds_low': 0}, {'wind_cdir': 'ESE', 'rh': 27, 'pod': 'd', 'timestamp_utc': '2021-06-15T12:00:00', 'pres': 883.112, 'solar_rad': 974.853, 'ozone': 328, 'weather': {'icon': 'c02d', 'code': 801, 'description': 'Few clouds'}, 'wind_gust_spd': 11.7118, 'timestamp_local': '2021-06-15T14:00:00', 'snow_depth': 0, 'clouds': 38, 'ts': 1623758400, 'wind_spd': 5.50618, 'pop': 0, 'wind_cdir_full': 'east-southeast', 'slp': 1016.89, 'dni': 937.94, 'dewpt': 6, 'snow': 0, 'uv': 7.58151, 'wind_dir': 111, 'clouds_hi': 2, 'precip': 0, 'vis': 24.128, 'dhi': 117.62, 'app_temp': 26.2, 'datetime': '2021-06-15:12', 'temp': 26.8, 'ghi': 1002.88, 'clouds_mid': 39, 'clouds_low': 0}, {'wind_cdir': 'SSE', 'rh': 24, 'pod': 'd', 'timestamp_utc': '2021-06-15T15:00:00', 'pres': 881.339, 'solar_rad': 565.139, 'ozone': 323, 'weather': {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}, 'wind_gust_spd': 12.2921, 'timestamp_local': '2021-06-15T17:00:00', 'snow_depth': 0, 'clouds': 76, 'ts': 1623769200, 'wind_spd': 4.28592, 'pop': 15, 'wind_cdir_full': 'south-southeast', 'slp': 1014.46, 'dni': 892.15, 'dewpt': 5.4, 'snow': 0, 'uv': 3.15302, 'wind_dir': 164, 'clouds_hi': 43, 'precip': 0.048828125, 'vis': 24.128, 'dhi': 107.98, 'app_temp': 26.9, 'datetime': '2021-06-15:15', 'temp': 28.1, 'ghi': 801.62, 'clouds_mid': 56, 'clouds_low': 0}, {'wind_cdir': 'S', 'rh': 28, 'pod': 'd', 'timestamp_utc': '2021-06-15T18:00:00', 'pres': 880.719, 'solar_rad': 170.431, 'ozone': 320.5, 'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 10.1157, 'timestamp_local': '2021-06-15T20:00:00', 'snow_depth': 0, 'clouds': 80, 'ts': 1623780000, 'wind_spd': 4.75035, 'pop': 15, 'wind_cdir_full': 'south', 'slp': 1013.91, 'dni': 647.18, 'dewpt': 6, 'snow': 0, 'uv': 0.813903, 'wind_dir': 169, 'clouds_hi': 12, 'precip': 0.021484375, 'vis': 19.2, 'dhi': 68.69, 'app_temp': 25.8, 'datetime': '2021-06-15:18', 'temp': 26.4, 'ghi': 262.69, 'clouds_mid': 78, 'clouds_low': 0}, {'wind_cdir': 'NE', 'rh': 48, 'pod': 'n', 'timestamp_utc': '2021-06-15T21:00:00', 'pres': 881.045, 'solar_rad': 0, 'ozone': 319, 'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'}, 'wind_gust_spd': 7.37562, 'timestamp_local': '2021-06-15T23:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623790800, 'wind_spd': 2.08412, 'pop': 10, 'wind_cdir_full': 'northeast', 'slp': 1015.38, 'dni': 0, 'dewpt': 9.5, 'snow': 0, 'uv': 0, 'wind_dir': 48, 'clouds_hi': 100, 'precip': 0.095703125, 'vis': 24.128, 'dhi': 0, 'app_temp': 20.8, 'datetime': '2021-06-15:21', 'temp': 21.4, 'ghi': 0, 'clouds_mid': 81, 'clouds_low': 8}, {'wind_cdir': 'E', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T00:00:00', 'pres': 881.915, 'solar_rad': 0, 'ozone': 324.75, 'weather': {'icon': 'r04n', 'code': 520, 'description': 'Light shower rain'}, 'wind_gust_spd': 9.4193, 'timestamp_local': '2021-06-16T02:00:00', 'snow_depth': 0, 'clouds': 100, 'ts': 1623801600, 'wind_spd': 1.0167, 'pop': 25, 'wind_cdir_full': 'east', 'slp': 1017.05, 'dni': 0, 'dewpt': 11.9, 'snow': 0, 'uv': 0, 'wind_dir': 90, 'clouds_hi': 100, 'precip': 0.33984375, 'vis': 24.128, 'dhi': 0, 'app_temp': 18.1, 'datetime': '2021-06-16:00', 'temp': 18.4, 'ghi': 0, 'clouds_mid': 70, 'clouds_low': 4}, {'wind_cdir': 'ENE', 'rh': 67, 'pod': 'n', 'timestamp_utc': '2021-06-16T03:00:00', 'pre ...
